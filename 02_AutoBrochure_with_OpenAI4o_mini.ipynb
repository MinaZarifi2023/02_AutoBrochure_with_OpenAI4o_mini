# %% [markdown]
# # 📄 Brochure Generator Using LLMs
# This project builds an automated solution to generate a company brochure using real website data and OpenAI's GPT-4o-mini model and Ollama.
# Business use case: Create engaging marketing brochures for potential clients, investors, and talent based on the company's public website.

# %% [markdown]
# # with OpenAI's GPT-4o-mini model

# %%
# === Imports ===
# Essential libraries for HTTP requests, HTML parsing, environment config, and OpenAI API interaction

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# === Load environment variables ===
# Load OpenAI API key from .env file and validate it
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key) > 10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? ")
# Out:
# There might be a problem with your API key?

# %%
# === Initialize model and OpenAI client ===
MODEL = 'gpt-4o-mini'
openai = OpenAI()

# %%
# === Website Representation Class ===
# Encapsulates logic for fetching and parsing a webpage. Extracts main content(no codes and images) and useful hyperlinks.

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    Represents a single website and provides methods to extract readable text and outbound links.
    """
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# Example initialization
ed = Website("https://en.wikipedia.org/wiki/OpenAI")
ed.links
# Out:
# ['#bodyContent',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_upload_wizard',
#  '/wiki/Special:SpecialPages',
#  '/wiki/Main_Page',
#  '/wiki/Special:Search',
#  'https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en',
#  '/w/index.php?title=Special:CreateAccount&returnto=OpenAI',
#  '/w/index.php?title=Special:UserLogin&returnto=OpenAI',
#  'https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en',
#  '/w/index.php?title=Special:CreateAccount&returnto=OpenAI',
#  '/w/index.php?title=Special:UserLogin&returnto=OpenAI',
#  '/wiki/Help:Introduction',
#  '/wiki/Special:MyContributions',
#  '/wiki/Special:MyTalk',
#  '#',
#  '#History',
#  '#2015:_founding_and_initial_motivations',
#  '#2016–2018:_Non-profit_beginnings',
#  '#2019:_Transition_from_non-profit',
#  '#2020–2023:_ChatGPT,_DALL-E,_partnership_with_Microsoft',
#  '#2024:_Public/Non-Profit_Efforts,_Sora,_Partnership_with_Apple',
#  '#2025',
#  '#Management',
#  '#Key_employees',
#  '#Board_of_directors_of_the_OpenAI_nonprofit',
#  '#Principal_individual_investors',
#  '#Strategy',
#  '#Stance_on_China',
#  '#Products_and_applications',
#  '#API',
#  '#Controversies',
#  '#Firing_of_Altman',
#  '#Content_moderation_contract_with_Sama',
#  '#Lack_of_technological_transparency',
#  '#Non-disparagement_agreement',
#  '#Proposed_shift_from_nonprofit_control',
#  '#Copyright_infringement_in_training_data',
#  '#GDPR_compliance',
#  '#Use_by_military',
#  '#Data_scraping',
#  '#Suicide_of_Suchir_Balaji',
#  '#See_also',
#  '#References',
#  '#Further_reading',
#  '#External_links',
#  'https://af.wikipedia.org/wiki/OpenAI',
#  'https://ang.wikipedia.org/wiki/OpenAI',
#  'https://ar.wikipedia.org/wiki/%D8%A3%D9%88%D8%A8%D9%86_%D8%A3%D9%8A%D9%87_%D8%A2%D9%8A',
#  'https://az.wikipedia.org/wiki/OpenAI',
#  'https://bn.wikipedia.org/wiki/%E0%A6%93%E0%A6%AA%E0%A7%87%E0%A6%A8%E0%A6%8F%E0%A6%86%E0%A6%87',
#  'https://zh-min-nan.wikipedia.org/wiki/OpenAI',
#  'https://be.wikipedia.org/wiki/OpenAI',
#  'https://bh.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88',
#  'https://bg.wikipedia.org/wiki/OpenAI',
#  'https://bs.wikipedia.org/wiki/OpenAI',
#  'https://br.wikipedia.org/wiki/OpenAI',
#  'https://ca.wikipedia.org/wiki/OpenAI',
#  'https://cs.wikipedia.org/wiki/OpenAI',
#  'https://cy.wikipedia.org/wiki/OpenAI',
#  'https://da.wikipedia.org/wiki/OpenAI',
#  'https://ary.wikipedia.org/wiki/%D8%A4%D9%BE%D9%86_%D8%A5%D9%8A_%D8%A3%D9%8A',
#  'https://de.wikipedia.org/wiki/OpenAI',
#  'https://et.wikipedia.org/wiki/OpenAI',
#  'https://el.wikipedia.org/wiki/OpenAI',
#  'https://es.wikipedia.org/wiki/OpenAI',
#  'https://eo.wikipedia.org/wiki/OpenAI',
#  'https://eu.wikipedia.org/wiki/OpenAI',
#  'https://fa.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86%E2%80%8C%D8%A7%DB%8C%E2%80%8C%D8%A2%DB%8C',
#  'https://fr.wikipedia.org/wiki/OpenAI',
#  'https://ga.wikipedia.org/wiki/OpenAI',
#  'https://gl.wikipedia.org/wiki/OpenAI',
#  'https://hak.wikipedia.org/wiki/OpenAI',
#  'https://ko.wikipedia.org/wiki/%EC%98%A4%ED%94%88AI',
#  'https://hy.wikipedia.org/wiki/OpenAI',
#  'https://hi.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88',
#  'https://hr.wikipedia.org/wiki/OpenAI',
#  'https://io.wikipedia.org/wiki/OpenAI',
#  'https://id.wikipedia.org/wiki/OpenAI',
#  'https://is.wikipedia.org/wiki/OpenAI',
#  'https://it.wikipedia.org/wiki/OpenAI',
#  'https://he.wikipedia.org/wiki/OpenAI',
#  'https://jv.wikipedia.org/wiki/OpenAI',
#  'https://kk.wikipedia.org/wiki/OpenAI',
#  'https://ky.wikipedia.org/wiki/OpenAI',
#  'https://lv.wikipedia.org/wiki/OpenAI',
#  'https://lt.wikipedia.org/wiki/OpenAI',
#  'https://hu.wikipedia.org/wiki/OpenAI',
#  'https://mk.wikipedia.org/wiki/OpenAI',
#  'https://ml.wikipedia.org/wiki/%E0%B4%93%E0%B4%AA%E0%B5%8D%E0%B4%AA%E0%B5%BA%E0%B4%8E%E0%B4%90',
#  'https://mr.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%AF',
#  'https://arz.wikipedia.org/wiki/%D8%A7%D9%88%D8%A8%D9%86_%D8%A7%D9%8A%D9%87_%D8%A7%D9%89',
#  'https://ms.wikipedia.org/wiki/OpenAI',
#  'https://my.wikipedia.org/wiki/OpenAI',
#  'https://nl.wikipedia.org/wiki/OpenAI',
#  'https://ne.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88',
#  'https://ja.wikipedia.org/wiki/OpenAI',
#  'https://no.wikipedia.org/wiki/OpenAI',
#  'https://nn.wikipedia.org/wiki/OpenAI',
#  'https://uz.wikipedia.org/wiki/OpenAI',
#  'https://pa.wikipedia.org/wiki/%E0%A8%93%E0%A8%AA%E0%A8%A8%E0%A8%8F%E0%A8%86%E0%A8%88',
#  'https://ps.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86_%D8%A7%DB%8C_%D8%A2%DB%8C',
#  'https://pms.wikipedia.org/wiki/OpenAI',
#  'https://pl.wikipedia.org/wiki/OpenAI',
#  'https://pt.wikipedia.org/wiki/OpenAI',
#  'https://kaa.wikipedia.org/wiki/OpenAI',
#  'https://ro.wikipedia.org/wiki/OpenAI',
#  'https://qu.wikipedia.org/wiki/OpenAI',
#  'https://ru.wikipedia.org/wiki/OpenAI',
#  'https://sah.wikipedia.org/wiki/OpenAI',
#  'https://sco.wikipedia.org/wiki/OpenAI',
#  'https://sq.wikipedia.org/wiki/OpenAI',
#  'https://simple.wikipedia.org/wiki/OpenAI',
#  'https://sl.wikipedia.org/wiki/OpenAI',
#  'https://so.wikipedia.org/wiki/OpenAI',
#  'https://ckb.wikipedia.org/wiki/%D8%A6%DB%86%D9%BE%D9%86_%D8%A6%DB%95%DB%8C_%D8%A6%D8%A7%DB%8C',
#  'https://sr.wikipedia.org/wiki/OpenAI',
#  'https://sh.wikipedia.org/wiki/OpenAI',
#  'https://fi.wikipedia.org/wiki/OpenAI',
#  'https://sv.wikipedia.org/wiki/Open_AI',
#  'https://tl.wikipedia.org/wiki/OpenAI',
#  'https://ta.wikipedia.org/wiki/%E0%AE%93%E0%AE%AA%E0%AE%BF%E0%AE%A9%E0%AF%8D%E0%AE%8F%E0%AE%90',
#  'https://tt.wikipedia.org/wiki/OpenAI',
#  'https://te.wikipedia.org/wiki/%E0%B0%92%E0%B0%AA%E0%B1%86%E0%B0%A8%E0%B1%8D%E2%80%8C%E0%B0%8F%E0%B0%90',
#  'https://th.wikipedia.org/wiki/%E0%B9%82%E0%B8%AD%E0%B9%80%E0%B8%9E%E0%B8%99%E0%B9%80%E0%B8%AD%E0%B9%84%E0%B8%AD',
#  'https://tg.wikipedia.org/wiki/OpenAI',
#  'https://tr.wikipedia.org/wiki/OpenAI',
#  'https://uk.wikipedia.org/wiki/OpenAI',
#  'https://ur.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86_%D8%A7%DB%92_%D8%A2%D8%A6%DB%8C',
#  'https://ug.wikipedia.org/wiki/OpenAI_(%D8%A6%D9%88%D9%BE%DB%90%D9%86_%D8%A6%DB%90%D9%8A_%D8%A6%D8%A7%D9%8A)',
#  'https://vi.wikipedia.org/wiki/OpenAI',
#  'https://zh-yue.wikipedia.org/wiki/OpenAI',
#  'https://zh.wikipedia.org/wiki/OpenAI',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q21708200#sitelinks-wikipedia',
#  '/wiki/OpenAI',
#  '/wiki/Talk:OpenAI',
#  '/wiki/OpenAI',
#  '/w/index.php?title=OpenAI&action=edit',
#  '/w/index.php?title=OpenAI&action=history',
#  '/wiki/OpenAI',
#  '/w/index.php?title=OpenAI&action=edit',
#  '/w/index.php?title=OpenAI&action=history',
#  '/wiki/Special:WhatLinksHere/OpenAI',
#  '/wiki/Special:RecentChangesLinked/OpenAI',
#  '//en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard',
#  '/w/index.php?title=OpenAI&oldid=1296780953',
#  '/w/index.php?title=OpenAI&action=info',
#  '/w/index.php?title=Special:CiteThisPage&page=OpenAI&id=1296780953&wpFormIdentifier=titleform',
#  '/w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FOpenAI',
#  '/w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FOpenAI',
#  '/w/index.php?title=Special:DownloadAsPdf&page=OpenAI&action=show-download-screen',
#  '/w/index.php?title=OpenAI&printable=yes',
#  'https://commons.wikimedia.org/wiki/Category:OpenAI',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q21708200',
#  '/wiki/OpenAL',
#  '/wiki/OpenAPI_(disambiguation)',
#  '/wiki/Open-source_artificial_intelligence',
#  '/wiki/File:OpenAI_logo_2025_(wordmark).svg',
#  '/wiki/Privately_held_company',
#  '/wiki/Artificial_intelligence',
#  '#cite_note-OpenCorporates-1',
#  '/wiki/Sam_Altman',
#  '/wiki/Elon_Musk',
#  '/wiki/Ilya_Sutskever',
#  '/wiki/Greg_Brockman',
#  '/wiki/Trevor_Blackwell',
#  '/wiki/Andrej_Karpathy',
#  '/wiki/Wojciech_Zaremba',
#  '/wiki/Third_Street_(San_Francisco)',
#  '/wiki/San_Francisco',
#  '#cite_note-2',
#  '/wiki/Bret_Taylor',
#  '/wiki/Chairman',
#  '/wiki/Sam_Altman',
#  '/wiki/Chief_executive_officer',
#  '/wiki/Greg_Brockman',
#  '/wiki/President_(corporate_title)',
#  '/wiki/Sarah_Friar',
#  '/wiki/Chief_financial_officer',
#  '#cite_note-NYT5-3',
#  '/wiki/OpenAI_Five',
#  '/wiki/GPT-1',
#  '/wiki/GPT-2',
#  '/wiki/GPT-3',
#  '/wiki/GPT-3#GPT-3.5',
#  '/wiki/GPT-4',
#  '/wiki/GPT-4o',
#  '/wiki/GPT-4.5',
#  '/wiki/GPT-4.1',
#  '/wiki/DALL%C2%B7E',
#  '/wiki/GPT-4o#GPT_Image_1',
#  '/wiki/OpenAI_Codex',
#  '/wiki/ChatGPT',
#  '/wiki/SearchGPT',
#  '/wiki/Sora_(text-to-video_model)',
#  '/wiki/OpenAI_o1',
#  '/wiki/OpenAI_o3',
#  '/wiki/OpenAI_o4-mini',
#  '/wiki/OpenAI_Operator',
#  '/wiki/ChatGPT_Deep_Research',
#  '/wiki/United_States_dollar',
#  '#cite_note-2024-fin-est-4',
#  '/wiki/Net_income',
#  '#cite_note-2024-fin-est-4',
#  '/wiki/Asset',
#  'https://www.wikidata.org/wiki/Q21708200?uselang=en#P2403',
#  '#cite_note-5',
#  'https://openai.com/',
#  '/wiki/Artificial_intelligence',
#  '/wiki/File:Dall-e_3_(jan_%2724)_artificial_intelligence_icon.png',
#  '/wiki/Artificial_intelligence#Goals',
#  '/wiki/Artificial_general_intelligence',
#  '/wiki/Intelligent_agent',
#  '/wiki/Recursive_self-improvement',
#  '/wiki/Automated_planning_and_scheduling',
#  '/wiki/Computer_vision',
#  '/wiki/General_game_playing',
#  '/wiki/Knowledge_representation_and_reasoning',
#  '/wiki/Natural_language_processing',
#  '/wiki/Robotics',
#  '/wiki/AI_safety',
#  '/wiki/Machine_learning',
#  '/wiki/Symbolic_artificial_intelligence',
#  '/wiki/Deep_learning',
#  '/wiki/Bayesian_network',
#  '/wiki/Evolutionary_algorithm',
#  '/wiki/Hybrid_intelligent_system',
#  '/wiki/Artificial_intelligence_systems_integration',
#  '/wiki/Applications_of_artificial_intelligence',
#  '/wiki/Machine_learning_in_bioinformatics',
#  '/wiki/Deepfake',
#  '/wiki/Machine_learning_in_earth_sciences',
#  '/wiki/Applications_of_artificial_intelligence#Finance',
#  '/wiki/Generative_artificial_intelligence',
#  '/wiki/Artificial_intelligence_art',
#  '/wiki/Generative_audio',
#  '/wiki/Music_and_artificial_intelligence',
#  '/wiki/Artificial_intelligence_in_government',
#  '/wiki/Artificial_intelligence_in_healthcare',
#  '/wiki/Artificial_intelligence_in_mental_health',
#  '/wiki/Artificial_intelligence_in_industry',
#  '/wiki/Machine_translation',
#  '/wiki/Artificial_intelligence_arms_race',
#  '/wiki/Machine_learning_in_physics',
#  '/wiki/List_of_artificial_intelligence_projects',
#  '/wiki/Philosophy_of_artificial_intelligence',
#  '/wiki/Artificial_consciousness',
#  '/wiki/Chinese_room',
#  '/wiki/Friendly_artificial_intelligence',
#  '/wiki/AI_control_problem',
#  '/wiki/AI_takeover',
#  '/wiki/Ethics_of_artificial_intelligence',
#  '/wiki/Existential_risk_from_artificial_general_intelligence',
#  '/wiki/Turing_test',
#  '/wiki/Uncanny_valley',
#  '/wiki/History_of_artificial_intelligence',
#  '/wiki/Timeline_of_artificial_intelligence',
#  '/wiki/Progress_in_artificial_intelligence',
#  '/wiki/AI_winter',
#  '/wiki/AI_boom',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '/wiki/Template:Artificial_intelligence',
#  '/wiki/Template_talk:Artificial_intelligence',
#  '/wiki/Special:EditPage/Template:Artificial_intelligence',
#  '/wiki/Artificial_intelligence',
#  '/wiki/San_Francisco',
#  '/wiki/Artificial_general_intelligence',
#  '#cite_note-OpenAI-2018-6',
#  '/wiki/AI_boom',
#  '#cite_note-7',
#  '/wiki/Large_language_model',
#  '/wiki/DALL-E',
#  '/wiki/Text-to-image_model',
#  '/wiki/Text-to-video_model',
#  '/wiki/Sora_(text-to-video_model)',
#  '#cite_note-8',
#  '#cite_note-9',
#  '/wiki/ChatGPT',
#  '/wiki/Generative_AI',
#  '/wiki/Nonprofit_organization',
#  '#cite_note-OpenCorporates-1',
#  '/wiki/Delaware_General_Corporation_Law',
#  '#cite_note-St-10',
#  '/wiki/Microsoft',
#  '#cite_note-11',
#  '#cite_note-12',
#  '/wiki/Cloud_computing',
#  '/wiki/Microsoft_Azure',
#  '#cite_note-13',
#  '/wiki/Copyright_infringement',
#  '/wiki/Removal_of_Sam_Altman_from_OpenAI',
#  '/wiki/AI_safety',
#  '#cite_note-14',
#  '#cite_note-15',
#  '/w/index.php?title=OpenAI&action=edit&section=1',
#  '/w/index.php?title=OpenAI&action=edit&section=2',
#  '/wiki/File:Pioneer_Building,_San_Francisco_(2019)_-1.jpg',
#  '/wiki/Pioneer_Building_(San_Francisco)',
#  '/wiki/Sam_Altman',
#  '/wiki/Elon_Musk',
#  '/wiki/Ilya_Sutskever',
#  '/wiki/Greg_Brockman',
#  '/wiki/Trevor_Blackwell',
#  '/wiki/Andrej_Karpathy',
#  '/wiki/Wojciech_Zaremba',
#  '#cite_note-16',
#  '/wiki/Reid_Hoffman',
#  '/wiki/Jessica_Livingston',
#  '/wiki/Peter_Thiel',
#  '/wiki/Amazon_Web_Services',
#  '/wiki/Infosys',
#  '/wiki/YC_research',
#  '#cite_note-17',
#  '#cite_note-18',
#  '#cite_note-St-10',
#  '/wiki/TechCrunch',
#  '/wiki/Open_Philanthropy',
#  '#cite_note-19',
#  '#cite_note-20',
#  '#cite_note-21',
#  '#cite_note-bbc-giants-22',
#  '#cite_note-23',
#  '/wiki/Pioneer_Building_(San_Francisco)',
#  '/wiki/Mission_District,_San_Francisco',
#  '#cite_note-24',
#  '#cite_note-technologyreview-25',
#  '#cite_note-OpenAI-2018-6',
#  '/wiki/AI_safety',
#  '/wiki/Existential_risk_from_artificial_general_intelligence',
#  '#cite_note-csmonitor-26',
#  '#cite_note-wired_inside-27',
#  '#cite_note-bbc-giants-22',
#  '#cite_note-bbc-giants-22',
#  '#cite_note-28',
#  '#cite_note-wired_far_more-29',
#  '/wiki/Vishal_Sikka',
#  '#cite_note-30',
#  '/wiki/Amazon.com',
#  '#cite_note-wired_far_more-29',
#  '/w/index.php?title=OpenAI&action=edit&section=3',
#  '/wiki/Wired_(magazine)',
#  '/wiki/Yoshua_Bengio',
#  '/wiki/Deep_learning',
#  '#cite_note-wired_inside2-31',
#  '#cite_note-wired_inside2-31',
#  '/wiki/Facebook',
#  '/wiki/Google',
#  '#cite_note-wired_inside2-31',
#  '/wiki/Peter_Lee_(computer_scientist)',
#  '/wiki/National_Football_League',
#  '#cite_note-wired_inside2-31',
#  '#cite_note-wired_inside2-31',
#  '#cite_note-wired_inside2-31',
#  '/wiki/Wojciech_Zaremba',
#  '#cite_note-wired_inside2-31',
#  '/wiki/Reinforcement_learning',
#  '#cite_note-Dave_Gershgorn-2016-32',
#  '/wiki/Nvidia',
#  '/wiki/Nvidia_DGX',
#  '#cite_note-33',
#  '#cite_note-34',
#  '#cite_note-35',
#  '#cite_note-36',
#  '#cite_note-37',
#  '#cite_note-38',
#  '#cite_note-39',
#  '/wiki/DeepMind',
#  '/wiki/Central_processing_unit',
#  '/wiki/Graphics_processing_unit',
#  '/wiki/Conflict_of_interest',
#  '/wiki/Tesla,_Inc.',
#  '/wiki/Tesla_Autopilot',
#  '#cite_note-musk_resigns-40',
#  '/wiki/GPT-2',
#  '#cite_note-guardian-41',
#  '/w/index.php?title=OpenAI&action=edit&section=4',
#  '#cite_note-42',
#  '#cite_note-wired_investors-43',
#  '/wiki/Google_Brain',
#  '/wiki/DeepMind',
#  '/wiki/Facebook',
#  '#cite_note-bloomberg_arm-44',
#  '#cite_note-45',
#  '/wiki/Equity_(finance)',
#  '#cite_note-46',
#  '/wiki/Microsoft_Azure',
#  '/wiki/Supercomputer',
#  '#cite_note-Langston_2023-47',
#  '#cite_note-Foley_2020-48',
#  '#cite_note-Engadget_2020-49',
#  '#cite_note-50',
#  '#cite_note-51',
#  '#cite_note-52',
#  '/wiki/Oren_Etzioni',
#  '/wiki/Allen_Institute_for_AI',
#  '/wiki/IBM',
#  '/wiki/Controlling_interest',
#  '/wiki/Fiduciary_duty',
#  '#cite_note-wired_investors-43',
#  '#cite_note-bloomberg_arm-44',
#  '#cite_note-53',
#  '/w/index.php?title=OpenAI&action=edit&section=5',
#  '/wiki/GPT-3',
#  '#cite_note-2020-06-11_Bloomberg-54',
#  '/wiki/Anthropic',
#  '#cite_note-55',
#  '/wiki/DALL-E',
#  '#cite_note-56',
#  '/wiki/File:UK_national_football_team_considering_compete_in_UEFA_Euro_and_FIFA_World_Cup_%E2%80%93_ChatGPT.jpg',
#  '/wiki/ChatGPT',
#  '/wiki/AI_boom',
#  '#cite_note-57',
#  '/wiki/ChatGPT',
#  '/wiki/Chatbot',
#  '#cite_note-58',
#  '/wiki/Reuters',
#  '#cite_note-59',
#  '#cite_note-60',
#  '#cite_note-61',
#  '#cite_note-62',
#  '#cite_note-63',
#  '/wiki/Bard_(chatbot)',
#  '#cite_note-64',
#  '#cite_note-65',
#  '/wiki/Microsoft_Bing',
#  '/wiki/Microsoft_Edge',
#  '/wiki/Microsoft_365',
#  '#cite_note-66',
#  '/wiki/Reid_Hoffman',
#  '/wiki/Greylock_Partners',
#  '/wiki/Inflection_AI',
#  '#cite_note-67',
#  '/wiki/GPT-4',
#  '#cite_note-68',
#  '/wiki/File:Ilya_Sutskever_and_Sam_Altman_in_TAU.jpg',
#  '/wiki/Tel_Aviv_University',
#  '/wiki/Superintelligence',
#  '#cite_note-OpenAI-Governance-69',
#  '/wiki/International_Atomic_Energy_Agency',
#  '#cite_note-OpenAI-Governance-69',
#  '#cite_note-70',
#  '/wiki/AI_alignment',
#  '#cite_note-71',
#  '/wiki/New_York_City',
#  '#cite_note-72',
#  '/wiki/Microsoft_Copilot',
#  '#cite_note-unify-73',
#  '/wiki/Windows_11',
#  '/wiki/Windows_10',
#  '/wiki/Android_(operating_system)',
#  '#cite_note-androidlaunch-74',
#  '/wiki/IOS',
#  '#cite_note-ioslaunch-75',
#  '/wiki/G42_(company)',
#  '#cite_note-76',
#  '#cite_note-77',
#  '#cite_note-78',
#  '#cite_note-79',
#  '/w/index.php?title=OpenAI&action=edit&section=6',
#  '/wiki/Arizona_State_University',
#  '#cite_note-80',
#  '#cite_note-81',
#  '/wiki/Sora_(text-to-video_model)',
#  '#cite_note-82',
#  '#cite_note-83',
#  '/wiki/Elon_Musk',
#  '#cite_note-84',
#  '#cite_note-85',
#  '#cite_note-86',
#  '#cite_note-87',
#  '/wiki/Ilya_Sutskever',
#  '/wiki/Jakub_Pachocki',
#  '/wiki/Jan_Leike',
#  '#cite_note-may14-88',
#  '#cite_note-89',
#  '/wiki/Reddit',
#  '#cite_note-90',
#  '/wiki/News_Corp',
#  '/wiki/Axios_(website)',
#  '/wiki/Vox_Media',
#  '#cite_note-91',
#  '/wiki/Apple_Inc.',
#  '/wiki/Apple_Intelligence',
#  '/wiki/IPhone',
#  '#cite_note-92',
#  '/wiki/Paul_Nakasone',
#  '#cite_note-93',
#  '#cite_note-94',
#  '/wiki/O1_(generative_pre-trained_transformer)',
#  '#cite_note-95',
#  '#cite_note-96',
#  '/wiki/Anthropic',
#  '/wiki/Greg_Brockman',
#  '#cite_note-97',
#  '/wiki/House_of_Lords',
#  '#cite_note-98',
#  '/wiki/Mira_Murati',
#  '#cite_note-99',
#  '#cite_note-100',
#  '#cite_note-101',
#  '#cite_note-102',
#  '#cite_note-103',
#  '#cite_note-104',
#  '/wiki/Sora_(text-to-video_model)',
#  '#cite_note-105',
#  '#cite_note-106',
#  '/wiki/OpenAI_o1',
#  '#cite_note-107',
#  '#cite_note-108',
#  '/wiki/OpenAI_o3',
#  '#cite_note-109',
#  '/w/index.php?title=OpenAI&action=edit&section=7',
#  '/wiki/DeepSeek',
#  '#cite_note-110',
#  '/wiki/Nvidia',
#  '#cite_note-111',
#  '/wiki/Oracle_Corporation',
#  '/wiki/SoftBank_Group',
#  '/wiki/MGX_(company)',
#  '/wiki/Stargate_LLC',
#  '/wiki/Federal_government_of_the_United_States',
#  '#cite_note-112',
#  '/wiki/AI_agent',
#  '#cite_note-113',
#  '#cite_note-114',
#  '/wiki/ChatGPT_Deep_Research',
#  '/wiki/Humanity%27s_Last_Exam',
#  '#cite_note-Verge_20250203-115',
#  '#cite_note-116',
#  '/wiki/Broadcom',
#  '/wiki/TSMC',
#  '#cite_note-117',
#  '#cite_note-118',
#  '#cite_note-119',
#  '/wiki/CoreWeave',
#  '#cite_note-120',
#  '/wiki/Coatue_Management',
#  '/wiki/Altimeter_Capital',
#  '/wiki/Thrive_Capital',
#  '#cite_note-121',
#  '#cite_note-122',
#  '#cite_note-123',
#  '#cite_note-124',
#  '#cite_note-125',
#  '#cite_note-126',
#  '/wiki/Io_(company)',
#  '/wiki/Jony_Ive',
#  '#cite_note-127',
#  '#cite_note-128',
#  '#cite_note-OpenAI-Sam_and_Jony-129',
#  '#cite_note-130',
#  '#cite_note-OpenAI-Sam_and_Jony-129',
#  '#cite_note-131',
#  '/w/index.php?title=OpenAI&action=edit&section=8',
#  '/wiki/File:OpenAI_corporate_structure.svg',
#  '/w/index.php?title=OpenAI&action=edit&section=9',
#  '/wiki/Sam_Altman',
#  '/wiki/Y_Combinator_(company)',
#  '/wiki/Greg_Brockman',
#  '/wiki/Stripe_(company)',
#  '#cite_note-seattle-investors-132',
#  '/wiki/Jakub_Pachocki',
#  '#cite_note-may14-88',
#  '/wiki/Y_Combinator_(company)',
#  '/wiki/JPMorgan_Chase',
#  '#cite_note-133',
#  '/wiki/Sarah_Friar',
#  '/wiki/Nextdoor',
#  '/wiki/Block,_Inc.',
#  '#cite_note-cxo_2024-134',
#  '/wiki/Twitter,_Inc.',
#  '/wiki/Meta_Platforms',
#  '#cite_note-cxo_2024-134',
#  '#cite_note-135',
#  '/wiki/Scott_Schools',
#  '/wiki/Uber_(company)',
#  '/w/index.php?title=OpenAI&action=edit&section=10',
#  '/wiki/Bret_Taylor',
#  '/wiki/Twitter,_Inc.',
#  '/wiki/Salesforce',
#  '/wiki/Sam_Altman',
#  '/wiki/Lawrence_Summers',
#  '/wiki/U.S._Secretary_of_the_Treasury',
#  '/wiki/President_of_Harvard_University',
#  '/wiki/Adam_D%27Angelo',
#  '/wiki/Quora',
#  '/wiki/Sue_Desmond-Hellmann',
#  '/wiki/Bill_%26_Melinda_Gates_Foundation',
#  '/wiki/Nicole_Seligman',
#  '/wiki/Sony_Corporation',
#  '/wiki/Fidji_Simo',
#  '/wiki/Instacart',
#  '/wiki/Paul_Nakasone',
#  '/wiki/National_Security_Agency',
#  '#cite_note-136',
#  '/wiki/Zico_Kolter',
#  '#cite_note-137',
#  '/wiki/Adebayo_Ogunlesi',
#  '/wiki/Global_Infrastructure_Partners',
#  '#cite_note-138',
#  '#cite_note-St-10',
#  '#cite_note-139',
#  '/w/index.php?title=OpenAI&action=edit&section=11',
#  '#cite_note-seattle-investors-132',
#  '/wiki/Reid_Hoffman',
#  '/wiki/LinkedIn',
#  '#cite_note-mercury-back-140',
#  '/wiki/Peter_Thiel',
#  '/wiki/PayPal',
#  '#cite_note-mercury-back-140',
#  '/wiki/Jessica_Livingston',
#  '/wiki/Elon_Musk',
#  '/w/index.php?title=OpenAI&action=edit&section=12',
#  '#cite_note-seattle-investors-132',
#  '/wiki/Nick_Bostrom',
#  '#cite_note-wired_inside-27',
#  '/wiki/Technological_singularity',
#  '#cite_note-141',
#  '#cite_note-142',
#  '/wiki/AI_alignment',
#  '/wiki/Artificial_general_intelligence',
#  '#cite_note-143',
#  '#cite_note-144',
#  '#cite_note-145',
#  '#cite_note-146',
#  '/wiki/Federal_preemption',
#  '#cite_note-roberts2025-147',
#  '#cite_note-148',
#  '/w/index.php?title=OpenAI&action=edit&section=13',
#  '/wiki/Sam_Altman',
#  '/wiki/People%27s_Republic_of_China',
#  '/wiki/United_States_sanctions_against_China',
#  '#cite_note-149',
#  '/wiki/DeepSeek',
#  '#cite_note-150',
#  '/wiki/Baidu',
#  '/wiki/Open-source',
#  '#cite_note-151',
#  '/w/index.php?title=OpenAI&action=edit&section=14',
#  '/wiki/Products_and_applications_of_OpenAI',
#  '/wiki/ChatGPT',
#  '/wiki/ChatGPT_Deep_Research',
#  '/wiki/DALL-E',
#  '/wiki/GPT-2',
#  '/wiki/GPT-3',
#  '/wiki/GPT-4',
#  '/wiki/OpenAI_Codex',
#  '/wiki/OpenAI_Five',
#  '/wiki/OpenAI_o1',
#  '/wiki/OpenAI_o3',
#  '/wiki/SearchGPT',
#  '/wiki/Sora_(text-to-video_model)',
#  '/wiki/Whisper_(speech_recognition_system)',
#  '/w/index.php?title=OpenAI&action=edit&section=15',
#  '/wiki/Products_and_applications_of_OpenAI#API',
#  'https://en.wikipedia.org/w/index.php?title=Products_and_applications_of_OpenAI&action=edit',
#  '/wiki/API',
#  '#cite_note-Products_and_applications_of_OpenAI_gpt3-whynotfullmodel-152',
#  '#cite_note-Products_and_applications_of_OpenAI_tech_Tech-153',
#  '/w/index.php?title=OpenAI&action=edit&section=16',
#  '/w/index.php?title=OpenAI&action=edit&section=17',
#  '/wiki/Removal_of_Sam_Altman_from_OpenAI',
#  '/wiki/Helen_Toner',
#  '/wiki/Ilya_Sutskever',
#  '/wiki/Adam_D%27Angelo',
#  '/wiki/Mira_Murati',
#  '/wiki/Greg_Brockman',
#  '#cite_note-154',
#  '#cite_note-guard-17nov2023-155',
#  '#cite_note-156',
#  '/w/index.php?title=Aleksander_M%C4%85dry&action=edit&redlink=1',
#  'https://pl.wikipedia.org/wiki/Aleksander_M%C4%85dry',
#  '#cite_note-157',
#  '#cite_note-158',
#  '/wiki/Thrive_Capital',
#  '#cite_note-159',
#  '#cite_note-160',
#  '#cite_note-161',
#  '/wiki/Emmett_Shear',
#  '#cite_note-162',
#  '/wiki/Anthropic',
#  '/wiki/Dario_Amodei',
#  '/wiki/Mergers_and_acquisitions',
#  '#cite_note-163',
#  '/wiki/Satya_Nadella',
#  '#cite_note-164',
#  '#cite_note-165',
#  '#cite_note-166',
#  '#cite_note-167',
#  '#cite_note-168',
#  '#cite_note-169',
#  '/wiki/Bret_Taylor',
#  '/wiki/Lawrence_Summers',
#  '#cite_note-170',
#  '#cite_note-gradeschool-171',
#  '#cite_note-172',
#  '#cite_note-173',
#  '#cite_note-Anna_Tong_2023_u135-174',
#  '#cite_note-175',
#  '#cite_note-176',
#  '/w/index.php?title=OpenAI&action=edit&section=18',
#  '/wiki/Content_moderation_and_working_conditions',
#  '/wiki/Labeled_data',
#  '/wiki/Sama_(company)',
#  '/wiki/Kenya',
#  '/wiki/Content_moderation',
#  '/wiki/Time_(magazine)',
#  '#cite_note-Time1-177',
#  '/w/index.php?title=OpenAI&action=edit&section=19',
#  '#cite_note-178',
#  '/w/index.php?title=OpenAI&action=edit&section=20',
#  '/wiki/Vox_(website)',
#  '/wiki/Non-disclosure_agreement',
#  '/wiki/Daniel_Kokotajlo_(researcher)',
#  '#cite_note-179',
#  '#cite_note-180',
#  '#cite_note-181',
#  '#cite_note-182',
#  '#cite_note-183',
#  '/w/index.php?title=OpenAI&action=edit&section=21',
#  '/wiki/Benefit_corporation',
#  '#cite_note-184',
#  'https://notforprivategain.org/',
#  '/wiki/Attorney_General_of_California',
#  '/wiki/Attorney_General_of_Delaware',
#  '#cite_note-185',
#  '#cite_note-Piper-2025-186',
#  '#cite_note-Reuters-2025-187',
#  '#cite_note-Piper-2025-186',
#  '#cite_note-188',
#  '#cite_note-Reuters-2025-187',
#  '#cite_note-189',
#  '#cite_note-Toonkel-2025-190',
#  '#cite_note-191',
#  '#cite_note-Toonkel-2025-190',
#  '/wiki/Bret_Taylor',
#  '#cite_note-192',
#  '#cite_note-193',
#  '/w/index.php?title=OpenAI&action=edit&section=22',
#  '/wiki/Copyright_infringement',
#  '/wiki/Sarah_Silverman',
#  '/wiki/Matthew_Butterick',
#  '/wiki/Paul_G._Tremblay',
#  '/wiki/Mona_Awad',
#  '#cite_note-194',
#  '#cite_note-Krithika-2023-195',
#  '#cite_note-196',
#  '/wiki/George_R._R._Martin',
#  '/wiki/John_Grisham',
#  '/wiki/Jodi_Picoult',
#  '/wiki/Jonathan_Franzen',
#  '/wiki/Authors_Guild',
#  '#cite_note-197',
#  '#cite_note-198',
#  '/wiki/New_York_Times',
#  '#cite_note-Krithika-2023-195',
#  '#cite_note-199',
#  '/wiki/GPT-3#Training_and_capabilities',
#  '#cite_note-200',
#  '/wiki/Speech_recognition',
#  '/wiki/Greg_Brockman',
#  '#cite_note-201',
#  '/wiki/The_Intercept',
#  '/wiki/Raw_Story',
#  '#cite_note-202',
#  '#cite_note-203',
#  '#cite_note-204',
#  '/wiki/United_States_Attorney_for_the_Southern_District_of_New_York',
#  '/wiki/The_Mercury_News',
#  '/wiki/The_Denver_Post',
#  '/wiki/The_Orange_County_Register',
#  '/wiki/St._Paul_Pioneer_Press',
#  '/wiki/Chicago_Tribune',
#  '/wiki/Orlando_Sentinel',
#  '/wiki/Sun_Sentinel',
#  '/wiki/New_York_Daily_News',
#  '#cite_note-ebt-30apr2024-205',
#  '/w/index.php?title=OpenAI&action=edit&section=23',
#  '/wiki/European_Data_Protection_Board',
#  '#cite_note-206',
#  '/wiki/NOYB',
#  '/wiki/Austria',
#  '/wiki/General_Data_Protection_Regulation',
#  '/wiki/Date_of_birth',
#  '#cite_note-207',
#  '/w/index.php?title=OpenAI&action=edit&section=24',
#  '#cite_note-208',
#  '#cite_note-209',
#  '/wiki/Large_language_model',
#  '/wiki/DARPA_Prize_Competitions',
#  '/wiki/DARPA',
#  '/wiki/Advanced_Research_Projects_Agency_for_Health',
#  '#cite_note-210',
#  '/wiki/The_Intercept',
#  '/wiki/United_States_Africa_Command',
#  '/wiki/United_States_Department_of_Defense',
#  '/wiki/Microsoft',
#  '#cite_note-intercept-africom-211',
#  '/wiki/Anduril_Industries',
#  '#cite_note-212',
#  '/w/index.php?title=Kevin_Weil&action=edit&redlink=1',
#  '/wiki/Lieutenant_colonel',
#  '/wiki/United_States_Army',
#  '/wiki/Detachment_201',
#  '#cite_note-213',
#  '#cite_note-214',
#  '#cite_note-215',
#  '/w/index.php?title=OpenAI&action=edit&section=25',
#  '/wiki/San_Francisco',
#  '/wiki/California',
#  '#cite_note-216',
#  '/wiki/Microsoft',
#  '#cite_note-217',
#  '/wiki/News_Corp',
#  '/wiki/The_Wall_Street_Journal',
#  '/wiki/New_York_Post',
#  '/wiki/The_Times',
#  '/wiki/The_Sunday_Times',
#  '/wiki/The_New_York_Times',
#  '/wiki/Microsoft',
#  '#cite_note-218',
#  '/wiki/Toronto_Star',
#  '/wiki/Metroland_Media_Group',
#  '/wiki/Postmedia_Network',
#  '/wiki/The_Globe_and_Mail',
#  '/wiki/The_Canadian_Press',
#  '/wiki/CBC_News',
#  '#cite_note-219',
#  '/w/index.php?title=OpenAI&action=edit&section=26',
#  '/wiki/Suchir_Balaji',
#  '/wiki/Suchir_Balaji',
#  '#cite_note-sf-standard-220',
#  '#cite_note-sf-standard-220',
#  '#cite_note-Mercury-jan-31-221',
#  '/wiki/Elon_Musk',
#  '/wiki/Tucker_Carlson',
#  '/wiki/Ro_Khanna',
#  '/wiki/Jackie_Fielder',
#  '#cite_note-rokhanna-222',
#  '#cite_note-sfexaminer-jan-23-223',
#  '#cite_note-sf-standard-220',
#  '/w/index.php?title=OpenAI&action=edit&section=27',
#  '/wiki/Anthropic',
#  '/wiki/Center_for_AI_Safety',
#  '/wiki/Future_of_Life_Institute',
#  '/wiki/Google_DeepMind',
#  '/wiki/Machine_Intelligence_Research_Institute',
#  '/wiki/Model_Context_Protocol',
#  '/wiki/XAI_(company)',
#  '/w/index.php?title=OpenAI&action=edit&section=28',
#  '#cite_ref-OpenCorporates_1-0',
#  '#cite_ref-OpenCorporates_1-1',
#  'https://opencorporates.com/companies/us_de/5902936',
#  '/wiki/OpenCorporates',
#  'https://web.archive.org/web/20230828053254/https://opencorporates.com/companies/us_de/5902936',
#  '#cite_ref-2',
#  'https://www.sfchronicle.com/realestate/article/openai-s-f-uber-lease-18451102.php',
#  '#cite_ref-NYT5_3-0',
#  'https://www.nytimes.com/2024/09/03/technology/openai-chatgpt-revenue.html',
#  '/wiki/New_York_Times',
#  'https://web.archive.org/web/20240907201621/https://www.nytimes.com/2024/09/03/technology/openai-chatgpt-revenue.html',
#  '#cite_ref-2024-fin-est_4-0',
#  '#cite_ref-2024-fin-est_4-1',
#  'https://www.wsj.com/tech/ai/openaiin-talks-for-huge-investment-round-valuing-it-up-to-300-billion-2a2d4327',
#  '/wiki/The_Wall_Street_Journal',
#  'https://archive.today/20250131020756/https://www.wsj.com/tech/ai/openaiin-talks-for-huge-investment-round-valuing-it-up-to-300-billion-2a2d4327',
#  '#cite_ref-5',
#  'https://fortune.com/2024/12/17/hundreds-openai-employees-10-million-payday-softbank-stock-tender-offer-details/',
#  '/wiki/Fortune_(magazine)',
#  'https://archive.today/20241220014336/https://fortune.com/2024/12/17/hundreds-openai-employees-10-million-payday-softbank-stock-tender-offer-details/',
#  '#cite_ref-OpenAI-2018_6-0',
#  '#cite_ref-OpenAI-2018_6-1',
#  'https://openai.com/charter',
#  'https://web.archive.org/web/20230714043611/https://openai.com/charter',
#  '#cite_ref-7',
#  'https://www.wsj.com/tech/ai/artificial-the-openai-story-21587cbd',
#  'https://web.archive.org/web/20231212151657/https://www.wsj.com/tech/ai/artificial-the-openai-story-21587cbd',
#  '#cite_ref-8',
#  'https://platform.openai.com/docs/models/overview',
#  'https://archive.today/20231119121512/https://platform.openai.com/docs/models',
#  '#cite_ref-9',
#  'https://analyticsindiamag.com/openai-steals-the-spotlight-with-sora-%E2%9C%A8/',
#  'https://web.archive.org/web/20240420120154/https://analyticsindiamag.com/openai-steals-the-spotlight-with-sora-%E2%9C%A8/',
#  '#cite_ref-St_10-0',
#  '#cite_ref-St_10-1',
#  '#cite_ref-St_10-2',
#  'https://openai.com/our-structure',
#  'https://web.archive.org/web/20230729203855/https://openai.com/our-structure',
#  '#cite_ref-11',
#  'https://www.bloomberg.com/opinion/articles/2024-10-21/who-owns-openai',
#  '/wiki/Bloomberg_News',
#  '#cite_ref-12',
#  'https://openai.com/index/openai-lp/',
#  '#cite_ref-13',
#  'https://www.theverge.com/2023/3/13/23637675/microsoft-chatgpt-bing-millions-dollars-supercomputer-openai',
#  'https://web.archive.org/web/20230330071711/https://www.theverge.com/2023/3/13/23637675/microsoft-chatgpt-bing-millions-dollars-supercomputer-openai',
#  '#cite_ref-14',
#  'https://fortune.com/2024/08/26/openai-agi-safety-researchers-exodus/',
#  '#cite_ref-15',
#  'https://fortune.com/2024/10/24/openai-miles-brundage-suchir-balaji-ai-safety-copyright-sam-altman-chatgpt/',
#  'https://web.archive.org/web/20241207180154/https://fortune.com/2024/10/24/openai-miles-brundage-suchir-balaji-ai-safety-copyright-sam-altman-chatgpt/',
#  '#cite_ref-16',
#  'https://observer.com/2024/07/openai-founders-career/',
#  '#cite_ref-17',
#  'https://openai.com/blog/introducing-openai/',
#  'https://web.archive.org/web/20170808104802/https://openai.com/blog/introducing-openai/',
#  '#cite_ref-18',
#  'https://www.vanityfair.com/news/2015/12/sam-altman-elon-musk-openai',
#  'https://web.archive.org/web/20230203201103/https://www.vanityfair.com/news/2015/12/sam-altman-elon-musk-openai',
#  '#cite_ref-19',
#  'https://archive.today/20230518211335/https://techcrunch.com/2023/05/17/elon-musk-used-to-say-he-put-100m-in-openai-but-now-its-50m-here-are-the-receipts/',
#  '/wiki/TechCrunch',
#  'https://techcrunch.com/2023/05/17/elon-musk-used-to-say-he-put-100m-in-openai-but-now-its-50m-here-are-the-receipts/',
#  '#cite_ref-20',
#  'https://apnews.com/article/openai-elon-musk-lawsuit-sam-altman-4a4c0a19316f849f65db9e6d2b0b7a6b',
#  '#cite_ref-21',
#  'https://blog.openai.com/introducing-openai/',
#  'https://web.archive.org/web/20190224031626/https://blog.openai.com/introducing-openai/',
#  '#cite_ref-bbc-giants_22-0',
#  '#cite_ref-bbc-giants_22-1',
#  '#cite_ref-bbc-giants_22-2',
#  'https://www.bbc.com/news/technology-35082344',
#  '/wiki/BBC_News',
#  'https://web.archive.org/web/20180314021831/http://www.bbc.com/news/technology-35082344',
#  '#cite_ref-23',
#  'https://www.wsj.com/tech/ai/open-ai-division-for-profit-da26c24b',
#  '/wiki/The_Wall_Street_Journal',
#  'https://archive.today/20240928001622/https://www.wsj.com/tech/ai/open-ai-division-for-profit-da26c24b',
#  '#cite_ref-24',
#  'https://gizmodo.com/elon-musks-neuralink-sought-to-open-an-animal-testing-f-1823167674',
#  'https://web.archive.org/web/20180924145028/https://gizmodo.com/elon-musks-neuralink-sought-to-open-an-animal-testing-f-1823167674',
#  '#cite_ref-technologyreview_25-0',
#  'https://www.technologyreview.com/s/615181/ai-openai-moonshot-elon-musk-sam-altman-greg-brockman-messy-secretive-reality/',
#  'https://web.archive.org/web/20200403023123/https://www.technologyreview.com/s/615181/ai-openai-moonshot-elon-musk-sam-altman-greg-brockman-messy-secretive-reality/',
#  '#cite_ref-csmonitor_26-0',
#  'http://www.csmonitor.com/Technology/2015/1214/Open-AI-Effort-to-democratize-artificial-intelligence-research',
#  '/wiki/The_Christian_Science_Monitor',
#  'https://web.archive.org/web/20151219071134/http://www.csmonitor.com/Technology/2015/1214/Open-AI-Effort-to-democratize-artificial-intelligence-research',
#  '#cite_ref-wired_inside_27-0',
#  '#cite_ref-wired_inside_27-1',
#  'https://www.wired.com/2016/04/openai-elon-musk-sam-altman-plan-to-set-artificial-intelligence-free/',
#  '/wiki/Wired_(magazine)',
#  'https://web.archive.org/web/20160427162700/http://www.wired.com/2016/04/openai-elon-musk-sam-altman-plan-to-set-artificial-intelligence-free/',
#  '#cite_ref-28',
#  'http://www.csmonitor.com/Science/2015/1214/Tech-leaders-launch-nonprofit-to-save-the-world-from-killer-robots',
#  '/wiki/The_Christian_Science_Monitor',
#  'https://web.archive.org/web/20180703170556/https://www.csmonitor.com/Science/2015/1214/Tech-leaders-launch-nonprofit-to-save-the-world-from-killer-robots',
#  '#cite_ref-wired_far_more_29-0',
#  '#cite_ref-wired_far_more_29-1',
#  'https://www.wired.com/2015/12/elon-musks-billion-dollar-ai-plan-is-about-far-more-than-saving-the-world/',
#  '/wiki/Wired_(magazine)',
#  'https://web.archive.org/web/20151219155928/http://www.wired.com/2015/12/elon-musks-billion-dollar-ai-plan-is-about-far-more-than-saving-the-world/',
#  '#cite_ref-30',
#  '/wiki/Vishal_Sikka',
#  'https://web.archive.org/web/20151222094518/http://www.infosysblogs.com/infytalk/2015/12/openai_ai_for_all.html',
#  '/wiki/Infosys',
#  'http://www.infosysblogs.com/infytalk/2015/12/openai_ai_for_all.html',
#  '#cite_ref-wired_inside2_31-0',
#  '#cite_ref-wired_inside2_31-1',
#  '#cite_ref-wired_inside2_31-2',
#  '#cite_ref-wired_inside2_31-3',
#  '#cite_ref-wired_inside2_31-4',
#  '#cite_ref-wired_inside2_31-5',
#  '#cite_ref-wired_inside2_31-6',
#  'https://www.wired.com/2016/04/openai-elon-musk-sam-altman-plan-to-set-artificial-intelligence-free/',
#  '/wiki/Wired_(magazine)',
#  'https://web.archive.org/web/20160427162700/http://www.wired.com/2016/04/openai-elon-musk-sam-altman-plan-to-set-artificial-intelligence-free/',
#  '#cite_ref-Dave_Gershgorn-2016_32-0',
#  'http://www.popsci.com/elon-musks-artificial-intelligence-group-opens-gym-to-train-ai',
#  'https://web.archive.org/web/20160430045139/http://www.popsci.com/elon-musks-artificial-intelligence-group-opens-gym-to-train-ai',
#  '#cite_ref-33',
#  'https://www.bloomberg.com/news/features/2023-06-15/nvidia-s-ai-chips-power-chatgpt-and-multibillion-dollar-surge',
#  'https://archive.today/20230618072913/https://www.bloomberg.com/news/features/2023-06-15/nvidia-s-ai-chips-power-chatgpt-and-multibillion-dollar-surge',
#  '#cite_ref-34',
#  'https://fortune.com/2016/08/15/elon-musk-artificial-intelligence-openai-nvidia-supercomputer/',
#  'https://archive.today/20230607233501/https://fortune.com/2016/08/15/elon-musk-artificial-intelligence-openai-nvidia-supercomputer/',
#  '#cite_ref-35',
#  'https://www.wired.com/2016/12/openais-universe-computers-learn-use-apps-like-humans/',
#  'https://web.archive.org/web/20190113173007/https://www.wired.com/2016/12/openais-universe-computers-learn-use-apps-like-humans/',
#  '#cite_ref-36',
#  'https://techcrunch.com/2016/12/05/openais-universe-is-the-fun-parent-every-artificial-intelligence-deserves/',
#  'https://web.archive.org/web/20190219080426/https://techcrunch.com/2016/12/05/openais-universe-is-the-fun-parent-every-artificial-intelligence-deserves/',
#  '#cite_ref-37',
#  'https://web.archive.org/web/20170101001551/https://universe.openai.com/',
#  'https://universe.openai.com/',
#  '#cite_ref-38',
#  'https://www.theregister.co.uk/2016/12/05/openai_universe_reinforcement_learning/',
#  'https://web.archive.org/web/20170101002022/http://www.theregister.co.uk/2016/12/05/openai_universe_reinforcement_learning/',
#  '#cite_ref-39',
#  'https://www.reuters.com/article/us-microsoft-openai/microsoft-to-invest-1-billion-in-openai-idUSKCN1UH1H9',
#  'https://web.archive.org/web/20200525132055/https://www.reuters.com/article/us-microsoft-openai/microsoft-to-invest-1-billion-in-openai-idUSKCN1UH1H9',
#  ...]

# %%
# === Step 1: Identify Relevant Pages for the Brochure ===
# Use LLM reasoning to classify useful links such as "About", "Careers", or "Company" pages.
# This step demonstrates the value of GPT models in semantic filtering tasks.

link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
# Create a user prompt dynamically using actual website links
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://en.wikipedia.org/wiki/OpenAI - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=OpenAI
# /w/index.php?title=Special:UserLogin&returnto=OpenAI
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=OpenAI
# /w/index.php?title=Special:UserLogin&returnto=OpenAI
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #History
# #2015:_founding_and_initial_motivations
# #2016–2018:_Non-profit_beginnings
# #2019:_Transition_from_non-profit
# #2020–2023:_ChatGPT,_DALL-E,_partnership_with_Microsoft
# #2024:_Public/Non-Profit_Efforts,_Sora,_Partnership_with_Apple
# #2025
# #Management
# #Key_employees
# #Board_of_directors_of_the_OpenAI_nonprofit
# #Principal_individual_investors
# #Strategy
# #Stance_on_China
# #Products_and_applications
# #API
# #Controversies
# #Firing_of_Altman
# #Content_moderation_contract_with_Sama
# #Lack_of_technological_transparency
# #Non-disparagement_agreement
# #Proposed_shift_from_nonprofit_control
# #Copyright_infringement_in_training_data
# #GDPR_compliance
# #Use_by_military
# #Data_scraping
# #Suicide_of_Suchir_Balaji
# #See_also
# #References
# #Further_reading
# #External_links
# https://af.wikipedia.org/wiki/OpenAI
# https://ang.wikipedia.org/wiki/OpenAI
# https://ar.wikipedia.org/wiki/%D8%A3%D9%88%D8%A8%D9%86_%D8%A3%D9%8A%D9%87_%D8%A2%D9%8A
# https://az.wikipedia.org/wiki/OpenAI
# https://bn.wikipedia.org/wiki/%E0%A6%93%E0%A6%AA%E0%A7%87%E0%A6%A8%E0%A6%8F%E0%A6%86%E0%A6%87
# https://zh-min-nan.wikipedia.org/wiki/OpenAI
# https://be.wikipedia.org/wiki/OpenAI
# https://bh.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88
# https://bg.wikipedia.org/wiki/OpenAI
# https://bs.wikipedia.org/wiki/OpenAI
# https://br.wikipedia.org/wiki/OpenAI
# https://ca.wikipedia.org/wiki/OpenAI
# https://cs.wikipedia.org/wiki/OpenAI
# https://cy.wikipedia.org/wiki/OpenAI
# https://da.wikipedia.org/wiki/OpenAI
# https://ary.wikipedia.org/wiki/%D8%A4%D9%BE%D9%86_%D8%A5%D9%8A_%D8%A3%D9%8A
# https://de.wikipedia.org/wiki/OpenAI
# https://et.wikipedia.org/wiki/OpenAI
# https://el.wikipedia.org/wiki/OpenAI
# https://es.wikipedia.org/wiki/OpenAI
# https://eo.wikipedia.org/wiki/OpenAI
# https://eu.wikipedia.org/wiki/OpenAI
# https://fa.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86%E2%80%8C%D8%A7%DB%8C%E2%80%8C%D8%A2%DB%8C
# https://fr.wikipedia.org/wiki/OpenAI
# https://ga.wikipedia.org/wiki/OpenAI
# https://gl.wikipedia.org/wiki/OpenAI
# https://hak.wikipedia.org/wiki/OpenAI
# https://ko.wikipedia.org/wiki/%EC%98%A4%ED%94%88AI
# https://hy.wikipedia.org/wiki/OpenAI
# https://hi.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88
# https://hr.wikipedia.org/wiki/OpenAI
# https://io.wikipedia.org/wiki/OpenAI
# https://id.wikipedia.org/wiki/OpenAI
# https://is.wikipedia.org/wiki/OpenAI
# https://it.wikipedia.org/wiki/OpenAI
# https://he.wikipedia.org/wiki/OpenAI
# https://jv.wikipedia.org/wiki/OpenAI
# https://kk.wikipedia.org/wiki/OpenAI
# https://ky.wikipedia.org/wiki/OpenAI
# https://lv.wikipedia.org/wiki/OpenAI
# https://lt.wikipedia.org/wiki/OpenAI
# https://hu.wikipedia.org/wiki/OpenAI
# https://mk.wikipedia.org/wiki/OpenAI
# https://ml.wikipedia.org/wiki/%E0%B4%93%E0%B4%AA%E0%B5%8D%E0%B4%AA%E0%B5%BA%E0%B4%8E%E0%B4%90
# https://mr.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%AF
# https://arz.wikipedia.org/wiki/%D8%A7%D9%88%D8%A8%D9%86_%D8%A7%D9%8A%D9%87_%D8%A7%D9%89
# https://ms.wikipedia.org/wiki/OpenAI
# https://my.wikipedia.org/wiki/OpenAI
# https://nl.wikipedia.org/wiki/OpenAI
# https://ne.wikipedia.org/wiki/%E0%A4%93%E0%A4%AA%E0%A4%A8%E0%A4%8F%E0%A4%86%E0%A4%88
# https://ja.wikipedia.org/wiki/OpenAI
# https://no.wikipedia.org/wiki/OpenAI
# https://nn.wikipedia.org/wiki/OpenAI
# https://uz.wikipedia.org/wiki/OpenAI
# https://pa.wikipedia.org/wiki/%E0%A8%93%E0%A8%AA%E0%A8%A8%E0%A8%8F%E0%A8%86%E0%A8%88
# https://ps.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86_%D8%A7%DB%8C_%D8%A2%DB%8C
# https://pms.wikipedia.org/wiki/OpenAI
# https://pl.wikipedia.org/wiki/OpenAI
# https://pt.wikipedia.org/wiki/OpenAI
# https://kaa.wikipedia.org/wiki/OpenAI
# https://ro.wikipedia.org/wiki/OpenAI
# https://qu.wikipedia.org/wiki/OpenAI
# https://ru.wikipedia.org/wiki/OpenAI
# https://sah.wikipedia.org/wiki/OpenAI
# https://sco.wikipedia.org/wiki/OpenAI
# https://sq.wikipedia.org/wiki/OpenAI
# https://simple.wikipedia.org/wiki/OpenAI
# https://sl.wikipedia.org/wiki/OpenAI
# https://so.wikipedia.org/wiki/OpenAI
# https://ckb.wikipedia.org/wiki/%D8%A6%DB%86%D9%BE%D9%86_%D8%A6%DB%95%DB%8C_%D8%A6%D8%A7%DB%8C
# https://sr.wikipedia.org/wiki/OpenAI
# https://sh.wikipedia.org/wiki/OpenAI
# https://fi.wikipedia.org/wiki/OpenAI
# https://sv.wikipedia.org/wiki/Open_AI
# https://tl.wikipedia.org/wiki/OpenAI
# https://ta.wikipedia.org/wiki/%E0%AE%93%E0%AE%AA%E0%AE%BF%E0%AE%A9%E0%AF%8D%E0%AE%8F%E0%AE%90
# https://tt.wikipedia.org/wiki/OpenAI
# https://te.wikipedia.org/wiki/%E0%B0%92%E0%B0%AA%E0%B1%86%E0%B0%A8%E0%B1%8D%E2%80%8C%E0%B0%8F%E0%B0%90
# https://th.wikipedia.org/wiki/%E0%B9%82%E0%B8%AD%E0%B9%80%E0%B8%9E%E0%B8%99%E0%B9%80%E0%B8%AD%E0%B9%84%E0%B8%AD
# https://tg.wikipedia.org/wiki/OpenAI
# https://tr.wikipedia.org/wiki/OpenAI
# https://uk.wikipedia.org/wiki/OpenAI
# https://ur.wikipedia.org/wiki/%D8%A7%D9%88%D9%BE%D9%86_%D8%A7%DB%92_%D8%A2%D8%A6%DB%8C
# https://ug.wikipedia.org/wiki/OpenAI_(%D8%A6%D9%88%D9%BE%DB%90%D9%86_%D8%A6%DB%90%D9%8A_%D8%A6%D8%A7%D9%8A)
# https://vi.wikipedia.org/wiki/OpenAI
# https://zh-yue.wikipedia.org/wiki/OpenAI
# https://zh.wikipedia.org/wiki/OpenAI
# https://www.wikidata.org/wiki/Special:EntityPage/Q21708200#sitelinks-wikipedia
# /wiki/OpenAI
# /wiki/Talk:OpenAI
# /wiki/OpenAI
# /w/index.php?title=OpenAI&action=edit
# /w/index.php?title=OpenAI&action=history
# /wiki/OpenAI
# /w/index.php?title=OpenAI&action=edit
# /w/index.php?title=OpenAI&action=history
# /wiki/Special:WhatLinksHere/OpenAI
# /wiki/Special:RecentChangesLinked/OpenAI
# //en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# /w/index.php?title=OpenAI&oldid=1296780953
# /w/index.php?title=OpenAI&action=info
# /w/index.php?title=Special:CiteThisPage&page=OpenAI&id=1296780953&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FOpenAI
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FOpenAI
# /w/index.php?title=Special:DownloadAsPdf&page=OpenAI&action=show-download-screen
# /w/index.php?title=OpenAI&printable=yes
# https://commons.wikimedia.org/wiki/Category:OpenAI
# https://www.wikidata.org/wiki/Special:EntityPage/Q21708200
# /wiki/OpenAL
# /wiki/OpenAPI_(disambiguation)
# /wiki/Open-source_artificial_intelligence
# /wiki/File:OpenAI_logo_2025_(wordmark).svg
# /wiki/Privately_held_company
# /wiki/Artificial_intelligence
# #cite_note-OpenCorporates-1
# /wiki/Sam_Altman
# /wiki/Elon_Musk
# /wiki/Ilya_Sutskever
# /wiki/Greg_Brockman
# /wiki/Trevor_Blackwell
# /wiki/Andrej_Karpathy
# /wiki/Wojciech_Zaremba
# /wiki/Third_Street_(San_Francisco)
# /wiki/San_Francisco
# #cite_note-2
# /wiki/Bret_Taylor
# /wiki/Chairman
# /wiki/Sam_Altman
# /wiki/Chief_executive_officer
# /wiki/Greg_Brockman
# /wiki/President_(corporate_title)
# /wiki/Sarah_Friar
# /wiki/Chief_financial_officer
# #cite_note-NYT5-3
# /wiki/OpenAI_Five
# /wiki/GPT-1
# /wiki/GPT-2
# /wiki/GPT-3
# /wiki/GPT-3#GPT-3.5
# /wiki/GPT-4
# /wiki/GPT-4o
# /wiki/GPT-4.5
# /wiki/GPT-4.1
# /wiki/DALL%C2%B7E
# /wiki/GPT-4o#GPT_Image_1
# /wiki/OpenAI_Codex
# /wiki/ChatGPT
# /wiki/SearchGPT
# /wiki/Sora_(text-to-video_model)
# /wiki/OpenAI_o1
# /wiki/OpenAI_o3
# /wiki/OpenAI_o4-mini
# /wiki/OpenAI_Operator
# /wiki/ChatGPT_Deep_Research
# /wiki/United_States_dollar
# #cite_note-2024-fin-est-4
# /wiki/Net_income
# #cite_note-2024-fin-est-4
# /wiki/Asset
# https://www.wikidata.org/wiki/Q21708200?uselang=en#P2403
# #cite_note-5
# https://openai.com/
# /wiki/Artificial_intelligence
# /wiki/File:Dall-e_3_(jan_%2724)_artificial_intelligence_icon.png
# /wiki/Artificial_intelligence#Goals
# /wiki/Artificial_general_intelligence
# /wiki/Intelligent_agent
# /wiki/Recursive_self-improvement
# /wiki/Automated_planning_and_scheduling
# /wiki/Computer_vision
# /wiki/General_game_playing
# /wiki/Knowledge_representation_and_reasoning
# /wiki/Natural_language_processing
# /wiki/Robotics
# /wiki/AI_safety
# /wiki/Machine_learning
# /wiki/Symbolic_artificial_intelligence
# /wiki/Deep_learning
# /wiki/Bayesian_network
# /wiki/Evolutionary_algorithm
# /wiki/Hybrid_intelligent_system
# /wiki/Artificial_intelligence_systems_integration
# /wiki/Applications_of_artificial_intelligence
# /wiki/Machine_learning_in_bioinformatics
# /wiki/Deepfake
# /wiki/Machine_learning_in_earth_sciences
# /wiki/Applications_of_artificial_intelligence#Finance
# /wiki/Generative_artificial_intelligence
# /wiki/Artificial_intelligence_art
# /wiki/Generative_audio
# /wiki/Music_and_artificial_intelligence
# /wiki/Artificial_intelligence_in_government
# /wiki/Artificial_intelligence_in_healthcare
# /wiki/Artificial_intelligence_in_mental_health
# /wiki/Artificial_intelligence_in_industry
# /wiki/Machine_translation
# /wiki/Artificial_intelligence_arms_race
# /wiki/Machine_learning_in_physics
# /wiki/List_of_artificial_intelligence_projects
# /wiki/Philosophy_of_artificial_intelligence
# /wiki/Artificial_consciousness
# /wiki/Chinese_room
# /wiki/Friendly_artificial_intelligence
# /wiki/AI_control_problem
# /wiki/AI_takeover
# /wiki/Ethics_of_artificial_intelligence
# /wiki/Existential_risk_from_artificial_general_intelligence
# /wiki/Turing_test
# /wiki/Uncanny_valley
# /wiki/History_of_artificial_intelligence
# /wiki/Timeline_of_artificial_intelligence
# /wiki/Progress_in_artificial_intelligence
# /wiki/AI_winter
# /wiki/AI_boom
# /wiki/Glossary_of_artificial_intelligence
# /wiki/Template:Artificial_intelligence
# /wiki/Template_talk:Artificial_intelligence
# /wiki/Special:EditPage/Template:Artificial_intelligence
# /wiki/Artificial_intelligence
# /wiki/San_Francisco
# /wiki/Artificial_general_intelligence
# #cite_note-OpenAI-2018-6
# /wiki/AI_boom
# #cite_note-7
# /wiki/Large_language_model
# /wiki/DALL-E
# /wiki/Text-to-image_model
# /wiki/Text-to-video_model
# /wiki/Sora_(text-to-video_model)
# #cite_note-8
# #cite_note-9
# /wiki/ChatGPT
# /wiki/Generative_AI
# /wiki/Nonprofit_organization
# #cite_note-OpenCorporates-1
# /wiki/Delaware_General_Corporation_Law
# #cite_note-St-10
# /wiki/Microsoft
# #cite_note-11
# #cite_note-12
# /wiki/Cloud_computing
# /wiki/Microsoft_Azure
# #cite_note-13
# /wiki/Copyright_infringement
# /wiki/Removal_of_Sam_Altman_from_OpenAI
# /wiki/AI_safety
# #cite_note-14
# #cite_note-15
# /w/index.php?title=OpenAI&action=edit&section=1
# /w/index.php?title=OpenAI&action=edit&section=2
# /wiki/File:Pioneer_Building,_San_Francisco_(2019)_-1.jpg
# /wiki/Pioneer_Building_(San_Francisco)
# /wiki/Sam_Altman
# /wiki/Elon_Musk
# /wiki/Ilya_Sutskever
# /wiki/Greg_Brockman
# /wiki/Trevor_Blackwell
# /wiki/Andrej_Karpathy
# /wiki/Wojciech_Zaremba
# #cite_note-16
# /wiki/Reid_Hoffman
# /wiki/Jessica_Livingston
# /wiki/Peter_Thiel
# /wiki/Amazon_Web_Services
# /wiki/Infosys
# /wiki/YC_research
# #cite_note-17
# #cite_note-18
# #cite_note-St-10
# /wiki/TechCrunch
# /wiki/Open_Philanthropy
# #cite_note-19
# #cite_note-20
# #cite_note-21
# #cite_note-bbc-giants-22
# #cite_note-23
# /wiki/Pioneer_Building_(San_Francisco)
# /wiki/Mission_District,_San_Francisco
# #cite_note-24
# #cite_note-technologyreview-25
# #cite_note-OpenAI-2018-6
# /wiki/AI_safety
# /wiki/Existential_risk_from_artificial_general_intelligence
# #cite_note-csmonitor-26
# #cite_note-wired_inside-27
# #cite_note-bbc-giants-22
# #cite_note-bbc-giants-22
# #cite_note-28
# #cite_note-wired_far_more-29
# /wiki/Vishal_Sikka
# #cite_note-30
# /wiki/Amazon.com
# #cite_note-wired_far_more-29
# /w/index.php?title=OpenAI&action=edit&section=3
# /wiki/Wired_(magazine)
# /wiki/Yoshua_Bengio
# /wiki/Deep_learning
# #cite_note-wired_inside2-31
# #cite_note-wired_inside2-31
# /wiki/Facebook
# /wiki/Google
# #cite_note-wired_inside2-31
# /wiki/Peter_Lee_(computer_scientist)
# /wiki/National_Football_League
# #cite_note-wired_inside2-31
# #cite_note-wired_inside2-31
# #cite_note-wired_inside2-31
# /wiki/Wojciech_Zaremba
# #cite_note-wired_inside2-31
# /wiki/Reinforcement_learning
# #cite_note-Dave_Gershgorn-2016-32
# /wiki/Nvidia
# /wiki/Nvidia_DGX
# #cite_note-33
# #cite_note-34
# #cite_note-35
# #cite_note-36
# #cite_note-37
# #cite_note-38
# #cite_note-39
# /wiki/DeepMind
# /wiki/Central_processing_unit
# /wiki/Graphics_processing_unit
# /wiki/Conflict_of_interest
# /wiki/Tesla,_Inc.
# /wiki/Tesla_Autopilot
# #cite_note-musk_resigns-40
# /wiki/GPT-2
# #cite_note-guardian-41
# /w/index.php?title=OpenAI&action=edit&section=4
# #cite_note-42
# #cite_note-wired_investors-43
# /wiki/Google_Brain
# /wiki/DeepMind
# /wiki/Facebook
# #cite_note-bloomberg_arm-44
# #cite_note-45
# /wiki/Equity_(finance)
# #cite_note-46
# /wiki/Microsoft_Azure
# /wiki/Supercomputer
# #cite_note-Langston_2023-47
# #cite_note-Foley_2020-48
# #cite_note-Engadget_2020-49
# #cite_note-50
# #cite_note-51
# #cite_note-52
# /wiki/Oren_Etzioni
# /wiki/Allen_Institute_for_AI
# /wiki/IBM
# /wiki/Controlling_interest
# /wiki/Fiduciary_duty
# #cite_note-wired_investors-43
# #cite_note-bloomberg_arm-44
# #cite_note-53
# /w/index.php?title=OpenAI&action=edit&section=5
# /wiki/GPT-3
# #cite_note-2020-06-11_Bloomberg-54
# /wiki/Anthropic
# #cite_note-55
# /wiki/DALL-E
# #cite_note-56
# /wiki/File:UK_national_football_team_considering_compete_in_UEFA_Euro_and_FIFA_World_Cup_%E2%80%93_ChatGPT.jpg
# /wiki/ChatGPT
# /wiki/AI_boom
# #cite_note-57
# /wiki/ChatGPT
# /wiki/Chatbot
# #cite_note-58
# /wiki/Reuters
# #cite_note-59
# #cite_note-60
# #cite_note-61
# #cite_note-62
# #cite_note-63
# /wiki/Bard_(chatbot)
# #cite_note-64
# #cite_note-65
# /wiki/Microsoft_Bing
# /wiki/Microsoft_Edge
# /wiki/Microsoft_365
# #cite_note-66
# /wiki/Reid_Hoffman
# /wiki/Greylock_Partners
# /wiki/Inflection_AI
# #cite_note-67
# /wiki/GPT-4
# #cite_note-68
# /wiki/File:Ilya_Sutskever_and_Sam_Altman_in_TAU.jpg
# /wiki/Tel_Aviv_University
# /wiki/Superintelligence
# #cite_note-OpenAI-Governance-69
# /wiki/International_Atomic_Energy_Agency
# #cite_note-OpenAI-Governance-69
# #cite_note-70
# /wiki/AI_alignment
# #cite_note-71
# /wiki/New_York_City
# #cite_note-72
# /wiki/Microsoft_Copilot
# #cite_note-unify-73
# /wiki/Windows_11
# /wiki/Windows_10
# /wiki/Android_(operating_system)
# #cite_note-androidlaunch-74
# /wiki/IOS
# #cite_note-ioslaunch-75
# /wiki/G42_(company)
# #cite_note-76
# #cite_note-77
# #cite_note-78
# #cite_note-79
# /w/index.php?title=OpenAI&action=edit&section=6
# /wiki/Arizona_State_University
# #cite_note-80
# #cite_note-81
# /wiki/Sora_(text-to-video_model)
# #cite_note-82
# #cite_note-83
# /wiki/Elon_Musk
# #cite_note-84
# #cite_note-85
# #cite_note-86
# #cite_note-87
# /wiki/Ilya_Sutskever
# /wiki/Jakub_Pachocki
# /wiki/Jan_Leike
# #cite_note-may14-88
# #cite_note-89
# /wiki/Reddit
# #cite_note-90
# /wiki/News_Corp
# /wiki/Axios_(website)
# /wiki/Vox_Media
# #cite_note-91
# /wiki/Apple_Inc.
# /wiki/Apple_Intelligence
# /wiki/IPhone
# #cite_note-92
# /wiki/Paul_Nakasone
# #cite_note-93
# #cite_note-94
# /wiki/O1_(generative_pre-trained_transformer)
# #cite_note-95
# #cite_note-96
# /wiki/Anthropic
# /wiki/Greg_Brockman
# #cite_note-97
# /wiki/House_of_Lords
# #cite_note-98
# /wiki/Mira_Murati
# #cite_note-99
# #cite_note-100
# #cite_note-101
# #cite_note-102
# #cite_note-103
# #cite_note-104
# /wiki/Sora_(text-to-video_model)
# #cite_note-105
# #cite_note-106
# /wiki/OpenAI_o1
# #cite_note-107
# #cite_note-108
# /wiki/OpenAI_o3
# #cite_note-109
# /w/index.php?title=OpenAI&action=edit&section=7
# /wiki/DeepSeek
# #cite_note-110
# /wiki/Nvidia
# #cite_note-111
# /wiki/Oracle_Corporation
# /wiki/SoftBank_Group
# /wiki/MGX_(company)
# /wiki/Stargate_LLC
# /wiki/Federal_government_of_the_United_States
# #cite_note-112
# /wiki/AI_agent
# #cite_note-113
# #cite_note-114
# /wiki/ChatGPT_Deep_Research
# /wiki/Humanity%27s_Last_Exam
# #cite_note-Verge_20250203-115
# #cite_note-116
# /wiki/Broadcom
# /wiki/TSMC
# #cite_note-117
# #cite_note-118
# #cite_note-119
# /wiki/CoreWeave
# #cite_note-120
# /wiki/Coatue_Management
# /wiki/Altimeter_Capital
# /wiki/Thrive_Capital
# #cite_note-121
# #cite_note-122
# #cite_note-123
# #cite_note-124
# #cite_note-125
# #cite_note-126
# /wiki/Io_(company)
# /wiki/Jony_Ive
# #cite_note-127
# #cite_note-128
# #cite_note-OpenAI-Sam_and_Jony-129
# #cite_note-130
# #cite_note-OpenAI-Sam_and_Jony-129
# #cite_note-131
# /w/index.php?title=OpenAI&action=edit&section=8
# /wiki/File:OpenAI_corporate_structure.svg
# /w/index.php?title=OpenAI&action=edit&section=9
# /wiki/Sam_Altman
# /wiki/Y_Combinator_(company)
# /wiki/Greg_Brockman
# /wiki/Stripe_(company)
# #cite_note-seattle-investors-132
# /wiki/Jakub_Pachocki
# #cite_note-may14-88
# /wiki/Y_Combinator_(company)
# /wiki/JPMorgan_Chase
# #cite_note-133
# /wiki/Sarah_Friar
# /wiki/Nextdoor
# /wiki/Block,_Inc.
# #cite_note-cxo_2024-134
# /wiki/Twitter,_Inc.
# /wiki/Meta_Platforms
# #cite_note-cxo_2024-134
# #cite_note-135
# /wiki/Scott_Schools
# /wiki/Uber_(company)
# /w/index.php?title=OpenAI&action=edit&section=10
# /wiki/Bret_Taylor
# /wiki/Twitter,_Inc.
# /wiki/Salesforce
# /wiki/Sam_Altman
# /wiki/Lawrence_Summers
# /wiki/U.S._Secretary_of_the_Treasury
# /wiki/President_of_Harvard_University
# /wiki/Adam_D%27Angelo
# /wiki/Quora
# /wiki/Sue_Desmond-Hellmann
# /wiki/Bill_%26_Melinda_Gates_Foundation
# /wiki/Nicole_Seligman
# /wiki/Sony_Corporation
# /wiki/Fidji_Simo
# /wiki/Instacart
# /wiki/Paul_Nakasone
# /wiki/National_Security_Agency
# #cite_note-136
# /wiki/Zico_Kolter
# #cite_note-137
# /wiki/Adebayo_Ogunlesi
# /wiki/Global_Infrastructure_Partners
# #cite_note-138
# #cite_note-St-10
# #cite_note-139
# /w/index.php?title=OpenAI&action=edit&section=11
# #cite_note-seattle-investors-132
# /wiki/Reid_Hoffman
# /wiki/LinkedIn
# #cite_note-mercury-back-140
# /wiki/Peter_Thiel
# /wiki/PayPal
# #cite_note-mercury-back-140
# /wiki/Jessica_Livingston
# /wiki/Elon_Musk
# /w/index.php?title=OpenAI&action=edit&section=12
# #cite_note-seattle-investors-132
# /wiki/Nick_Bostrom
# #cite_note-wired_inside-27
# /wiki/Technological_singularity
# #cite_note-141
# #cite_note-142
# /wiki/AI_alignment
# /wiki/Artificial_general_intelligence
# #cite_note-143
# #cite_note-144
# #cite_note-145
# #cite_note-146
# /wiki/Federal_preemption
# #cite_note-roberts2025-147
# #cite_note-148
# /w/index.php?title=OpenAI&action=edit&section=13
# /wiki/Sam_Altman
# /wiki/People%27s_Republic_of_China
# /wiki/United_States_sanctions_against_China
# #cite_note-149
# /wiki/DeepSeek
# #cite_note-150
# /wiki/Baidu
# /wiki/Open-source
# #cite_note-151
# /w/index.php?title=OpenAI&action=edit&section=14
# /wiki/Products_and_applications_of_OpenAI
# /wiki/ChatGPT
# /wiki/ChatGPT_Deep_Research
# /wiki/DALL-E
# /wiki/GPT-2
# /wiki/GPT-3
# /wiki/GPT-4
# /wiki/OpenAI_Codex
# /wiki/OpenAI_Five
# /wiki/OpenAI_o1
# /wiki/OpenAI_o3
# /wiki/SearchGPT
# /wiki/Sora_(text-to-video_model)
# /wiki/Whisper_(speech_recognition_system)
# /w/index.php?title=OpenAI&action=edit&section=15
# /wiki/Products_and_applications_of_OpenAI#API
# https://en.wikipedia.org/w/index.php?title=Products_and_applications_of_OpenAI&action=edit
# /wiki/API
# #cite_note-Products_and_applications_of_OpenAI_gpt3-whynotfullmodel-152
# #cite_note-Products_and_applications_of_OpenAI_tech_Tech-153
# /w/index.php?title=OpenAI&action=edit&section=16
# /w/index.php?title=OpenAI&action=edit&section=17
# /wiki/Removal_of_Sam_Altman_from_OpenAI
# /wiki/Helen_Toner
# /wiki/Ilya_Sutskever
# /wiki/Adam_D%27Angelo
# /wiki/Mira_Murati
# /wiki/Greg_Brockman
# #cite_note-154
# #cite_note-guard-17nov2023-155
# #cite_note-156
# /w/index.php?title=Aleksander_M%C4%85dry&action=edit&redlink=1
# https://pl.wikipedia.org/wiki/Aleksander_M%C4%85dry
# #cite_note-157
# #cite_note-158
# /wiki/Thrive_Capital
# #cite_note-159
# #cite_note-160
# #cite_note-161
# /wiki/Emmett_Shear
# #cite_note-162
# /wiki/Anthropic
# /wiki/Dario_Amodei
# /wiki/Mergers_and_acquisitions
# #cite_note-163
# /wiki/Satya_Nadella
# #cite_note-164
# #cite_note-165
# #cite_note-166
# #cite_note-167
# #cite_note-168
# #cite_note-169
# /wiki/Bret_Taylor
# /wiki/Lawrence_Summers
# #cite_note-170
# #cite_note-gradeschool-171
# #cite_note-172
# #cite_note-173
# #cite_note-Anna_Tong_2023_u135-174
# #cite_note-175
# #cite_note-176
# /w/index.php?title=OpenAI&action=edit&section=18
# /wiki/Content_moderation_and_working_conditions
# /wiki/Labeled_data
# /wiki/Sama_(company)
# /wiki/Kenya
# /wiki/Content_moderation
# /wiki/Time_(magazine)
# #cite_note-Time1-177
# /w/index.php?title=OpenAI&action=edit&section=19
# #cite_note-178
# /w/index.php?title=OpenAI&action=edit&section=20
# /wiki/Vox_(website)
# /wiki/Non-disclosure_agreement
# /wiki/Daniel_Kokotajlo_(researcher)
# #cite_note-179
# #cite_note-180
# #cite_note-181
# #cite_note-182
# #cite_note-183
# /w/index.php?title=OpenAI&action=edit&section=21
# /wiki/Benefit_corporation
# #cite_note-184
# https://notforprivategain.org/
# /wiki/Attorney_General_of_California
# /wiki/Attorney_General_of_Delaware
# #cite_note-185
# #cite_note-Piper-2025-186
# #cite_note-Reuters-2025-187
# #cite_note-Piper-2025-186
# #cite_note-188
# #cite_note-Reuters-2025-187
# #cite_note-189
# #cite_note-Toonkel-2025-190
# #cite_note-191
# #cite_note-Toonkel-2025-190
# /wiki/Bret_Taylor
# #cite_note-192
# #cite_note-193
# /w/index.php?title=OpenAI&action=edit&section=22
# /wiki/Copyright_infringement
# /wiki/Sarah_Silverman
# /wiki/Matthew_Butterick
# /wiki/Paul_G._Tremblay
# /wiki/Mona_Awad
# #cite_note-194
# #cite_note-Krithika-2023-195
# #cite_note-196
# /wiki/George_R._R._Martin
# /wiki/John_Grisham
# /wiki/Jodi_Picoult
# /wiki/Jonathan_Franzen
# /wiki/Authors_Guild
# #cite_note-197
# #cite_note-198
# /wiki/New_York_Times
# #cite_note-Krithika-2023-195
# #cite_note-199
# /wiki/GPT-3#Training_and_capabilities
# #cite_note-200
# /wiki/Speech_recognition
# /wiki/Greg_Brockman
# #cite_note-201
# /wiki/The_Intercept
# /wiki/Raw_Story
# #cite_note-202
# #cite_note-203
# #cite_note-204
# /wiki/United_States_Attorney_for_the_Southern_District_of_New_York
# /wiki/The_Mercury_News
# /wiki/The_Denver_Post
# /wiki/The_Orange_County_Register
# /wiki/St._Paul_Pioneer_Press
# /wiki/Chicago_Tribune
# /wiki/Orlando_Sentinel
# /wiki/Sun_Sentinel
# /wiki/New_York_Daily_News
# #cite_note-ebt-30apr2024-205
# /w/index.php?title=OpenAI&action=edit&section=23
# /wiki/European_Data_Protection_Board
# #cite_note-206
# /wiki/NOYB
# /wiki/Austria
# /wiki/General_Data_Protection_Regulation
# /wiki/Date_of_birth
# #cite_note-207
# /w/index.php?title=OpenAI&action=edit&section=24
# #cite_note-208
# #cite_note-209
# /wiki/Large_language_model
# /wiki/DARPA_Prize_Competitions
# /wiki/DARPA
# /wiki/Advanced_Research_Projects_Agency_for_Health
# #cite_note-210
# /wiki/The_Intercept
# /wiki/United_States_Africa_Command
# /wiki/United_States_Department_of_Defense
# /wiki/Microsoft
# #cite_note-intercept-africom-211
# /wiki/Anduril_Industries
# #cite_note-212
# /w/index.php?title=Kevin_Weil&action=edit&redlink=1
# /wiki/Lieutenant_colonel
# /wiki/United_States_Army
# /wiki/Detachment_201
# #cite_note-213
# #cite_note-214
# #cite_note-215
# /w/index.php?title=OpenAI&action=edit&section=25
# /wiki/San_Francisco
# /wiki/California
# #cite_note-216
# /wiki/Microsoft
# #cite_note-217
# /wiki/News_Corp
# /wiki/The_Wall_Street_Journal
# /wiki/New_York_Post
# /wiki/The_Times
# /wiki/The_Sunday_Times
# /wiki/The_New_York_Times
# /wiki/Microsoft
# #cite_note-218
# /wiki/Toronto_Star
# /wiki/Metroland_Media_Group
# /wiki/Postmedia_Network
# /wiki/The_Globe_and_Mail
# /wiki/The_Canadian_Press
# /wiki/CBC_News
# #cite_note-219
# /w/index.php?title=OpenAI&action=edit&section=26
# /wiki/Suchir_Balaji
# /wiki/Suchir_Balaji
# #cite_note-sf-standard-220
# #cite_note-sf-standard-220
# #cite_note-Mercury-jan-31-221
# /wiki/Elon_Musk
# /wiki/Tucker_Carlson
# /wiki/Ro_Khanna
# /wiki/Jackie_Fielder
# #cite_note-rokhanna-222
# #cite_note-sfexaminer-jan-23-223
# #cite_note-sf-standard-220
# /w/index.php?title=OpenAI&action=edit&section=27
# /wiki/Anthropic
# /wiki/Center_for_AI_Safety
# /wiki/Future_of_Life_Institute
# /wiki/Google_DeepMind
# /wiki/Machine_Intelligence_Research_Institute
# /wiki/Model_Context_Protocol
# /wiki/XAI_(company)
# /w/index.php?title=OpenAI&action=edit&section=28
# #cite_ref-OpenCorporates_1-0
# #cite_ref-OpenCorporates_1-1
# https://opencorporates.com/companies/us_de/5902936
# /wiki/OpenCorporates
# https://web.archive.org/web/20230828053254/https://opencorporates.com/companies/us_de/5902936
# #cite_ref-2
# https://www.sfchronicle.com/realestate/article/openai-s-f-uber-lease-18451102.php
# #cite_ref-NYT5_3-0
# https://www.nytimes.com/2024/09/03/technology/openai-chatgpt-revenue.html
# /wiki/New_York_Times
# https://web.archive.org/web/20240907201621/https://www.nytimes.com/2024/09/03/technology/openai-chatgpt-revenue.html
# #cite_ref-2024-fin-est_4-0
# #cite_ref-2024-fin-est_4-1
# https://www.wsj.com/tech/ai/openaiin-talks-for-huge-investment-round-valuing-it-up-to-300-billion-2a2d4327
# /wiki/The_Wall_Street_Journal
# https://archive.today/20250131020756/https://www.wsj.com/tech/ai/openaiin-talks-for-huge-investment-round-valuing-it-up-to-300-billion-2a2d4327
# #cite_ref-5
# https://fortune.com/2024/12/17/hundreds-openai-employees-10-million-payday-softbank-stock-tender-offer-details/
# #cite_ref-Mercury-jan-31_221-0
# https://www.mercurynews.com/2025/01/31/family-of-openai-whistleblower-suchir-balaji-files-lawsuit-seeking-san-francisco-police-records/
# /wiki/The_Mercury_News
# #cite_ref-rokhanna_222-0
# https://www.chicagotribune.com/2025/01/15/openai-whistleblower-death/
# /wiki/Chicago_Tribune
# /wiki/Bay_Area_News_Group
# https://archive.today/20250130154936/https://www.chicagotribune.com/2025/01/15/openai-whistleblower-death/
# #cite_ref-sfexaminer-jan-23_223-0
# https://www.sfexaminer.com/news/technology/bay-area-officials-say-suchir-balaji-death-must-prompt-probe/article_8f1d1596-d923-11ef-8109-7f47649f523f.html
# /wiki/San_Francisco_Examiner
# /w/index.php?title=OpenAI&action=edit&section=29
# /wiki/Steven_Levy
# https://www.wired.com/story/what-openai-really-wants
# /wiki/Wired_(magazine)
# /wiki/ISSN_(identifier)
# https://search.worldcat.org/issn/1078-3148
# https://web.archive.org/web/20230906191725/https://www.wired.com/story/what-openai-really-wants/
# /wiki/Charles_Duhigg
# https://www.newyorker.com/magazine/2023/12/11/the-inside-story-of-microsofts-partnership-with-openai
# /wiki/The_New_Yorker
# /wiki/ISSN_(identifier)
# https://search.worldcat.org/issn/0028-792X
# https://archive.today/20231222230940/https://www.newyorker.com/magazine/2023/12/11/the-inside-story-of-microsofts-partnership-with-openai
# /w/index.php?title=OpenAI&action=edit&section=30
# /wiki/File:Commons-logo.svg
# https://commons.wikimedia.org/wiki/Category:OpenAI
# https://openai.com/
# https://www.wikidata.org/wiki/Q21708200#P856
# /wiki/Template:OpenAI
# /wiki/Template_talk:OpenAI
# /wiki/Special:EditPage/Template:OpenAI
# /wiki/Products_and_applications_of_OpenAI
# /wiki/Chatbot
# /wiki/ChatGPT
# /wiki/ChatGPT_in_education
# /wiki/GPT_Store
# /wiki/DALL-E
# /wiki/ChatGPT_Search
# /wiki/Sora_(text-to-video_model)
# /wiki/Whisper_(speech_recognition_system)
# /wiki/GitHub_Copilot
# /wiki/Foundation_model
# /wiki/OpenAI_Codex
# /wiki/Generative_pre-trained_transformer
# /wiki/GPT-1
# /wiki/GPT-2
# /wiki/GPT-3
# /wiki/GPT-4
# /wiki/GPT-4o
# /wiki/OpenAI_o1
# /wiki/OpenAI_o3
# /wiki/GPT-4.5
# /wiki/GPT-4.1
# /wiki/OpenAI_o4
# /wiki/Intelligent_agent
# /wiki/ChatGPT_Deep_Research
# /wiki/OpenAI_Operator
# /wiki/File:OpenAI_logo_2025_(wordmark).svg
# /wiki/Senior_management
# /wiki/Sam_Altman
# /wiki/Removal_of_Sam_Altman_from_OpenAI
# /wiki/Greg_Brockman
# /wiki/Sarah_Friar
# /wiki/Jakub_Pachocki
# /wiki/Scott_Schools
# /wiki/Mira_Murati
# /wiki/Emmett_Shear
# /wiki/Board_of_directors
# /wiki/Sam_Altman
# /wiki/Adam_D%27Angelo
# /wiki/Sue_Desmond-Hellmann
# /wiki/Zico_Kolter
# /wiki/Paul_Nakasone
# /wiki/Adebayo_Ogunlesi
# /wiki/Nicole_Seligman
# /wiki/Fidji_Simo
# /wiki/Lawrence_Summers
# /wiki/Bret_Taylor
# /wiki/Greg_Brockman
# /wiki/Reid_Hoffman
# /wiki/Will_Hurd
# /wiki/Holden_Karnofsky
# /wiki/Elon_Musk
# /wiki/Ilya_Sutskever
# /wiki/Helen_Toner
# /wiki/Shivon_Zilis
# /wiki/Joint_venture
# /wiki/Stargate_LLC
# /wiki/Apple_Intelligence
# /wiki/AI_Dungeon
# /wiki/AutoGPT
# /wiki/Deep_Learning_(South_Park)
# /wiki/LangChain
# /wiki/Microsoft_Copilot
# /wiki/OpenAI_Five
# /wiki/Transformer_(deep_learning_architecture)
# /wiki/Category:OpenAI
# /wiki/Template:Generative_AI
# /wiki/Template_talk:Generative_AI
# /wiki/Special:EditPage/Template:Generative_AI
# /wiki/Generative_artificial_intelligence
# /wiki/Autoencoder
# /wiki/Deep_learning
# /wiki/Fine-tuning_(deep_learning)
# /wiki/Foundation_model
# /wiki/Generative_adversarial_network
# /wiki/Generative_pre-trained_transformer
# /wiki/Large_language_model
# /wiki/Model_Context_Protocol
# /wiki/Neural_network_(machine_learning)
# /wiki/Prompt_engineering
# /wiki/Reinforcement_learning_from_human_feedback
# /wiki/Retrieval-augmented_generation
# /wiki/Self-supervised_learning
# /wiki/Stochastic_parrot
# /wiki/Synthetic_data
# /wiki/Top-p_sampling
# /wiki/Transformer_(deep_learning_architecture)
# /wiki/Variational_autoencoder
# /wiki/Vibe_coding
# /wiki/Vision_transformer
# /wiki/Waluigi_effect
# /wiki/Word_embedding
# /wiki/Character.ai
# /wiki/Claude_(language_model)
# /wiki/DBRX
# /wiki/DeepSeek_(chatbot)
# /wiki/Ernie_Bot
# /wiki/Gemini_(chatbot)
# /wiki/Generative_pre-trained_transformer
# /wiki/GPT-1
# /wiki/GPT-2
# /wiki/GPT-3
# /wiki/GPT-J
# /wiki/ChatGPT
# /wiki/GPT-4
# /wiki/GPT-4o
# /wiki/OpenAI_o1
# /wiki/OpenAI_o3
# /wiki/GPT-4.5
# /wiki/GPT-4.1
# /wiki/OpenAI_o4-mini
# /wiki/IBM_Granite
# /wiki/Grok_(chatbot)
# /wiki/Tencent#Research
# /wiki/Moonshot_AI#Kimi
# /wiki/Llama_(language_model)
# /wiki/Microsoft_Copilot
# /wiki/MiniMax_(company)#Technology
# /wiki/Mistral_AI#Mistral_Large
# /wiki/Huawei_PanGu
# /wiki/Qwen
# /wiki/YandexGPT
# /wiki/Claude_(language_model)
# /wiki/Cursor_(code_editor)
# /wiki/Mistral_AI
# /wiki/GitHub_Copilot
# /wiki/IBM_Granite#Foundation_models
# /wiki/Moonshot_AI
# /wiki/Replit
# /wiki/Xcode
# /wiki/Text-to-image_model
# /wiki/Aurora_(text-to-image_model)
# /wiki/Adobe_Firefly
# /wiki/Flux_(text-to-image_model)
# /wiki/GPT-4o#GPT_Image_1
# /wiki/Ideogram_(text-to-image_model)
# /wiki/Imagen_(text-to-image_model)
# /wiki/Canva#Acquisitions
# /wiki/Midjourney
# /wiki/ByteDance
# /wiki/Stable_Diffusion
# /wiki/Text-to-video_model
# /wiki/Dream_Machine_(text-to-video_model)
# /wiki/Runway_(company)#Gen-4
# /wiki/MiniMax_(company)#Hailuo_AI
# /wiki/Kling_(text-to-video_model)
# /wiki/Midjourney
# /wiki/ByteDance
# /wiki/Sora_(text-to-video_model)
# /wiki/Veo_(text-to-video_model)
# /wiki/Alibaba_Group#Cloud_computing_and_artificial_intelligence_technology
# /wiki/Speech_synthesis#Text-to-speech_systems
# /wiki/15.ai
# /wiki/ElevenLabs
# /wiki/MiniMax_(company)#Technology
# /wiki/WaveNet
# /wiki/Endel_(app)
# /wiki/Google_DeepMind#Music_generation
# /wiki/Riffusion
# /wiki/Suno_AI
# /wiki/Udio
# /wiki/Intelligent_agent
# /wiki/Zhipu_AI#AutoGLM
# /wiki/AutoGPT
# /wiki/Devin_AI
# /wiki/Manus_(AI_agent)
# /wiki/OpenAI_Codex
# /wiki/OpenAI_Operator
# /wiki/List_of_artificial_intelligence_companies
# /wiki/01.AI
# /wiki/Aleph_Alpha
# /wiki/Alibaba_Group
# /wiki/Anthropic
# /wiki/Baichuan
# /wiki/Baidu
# /wiki/ByteDance
# /wiki/Canva
# /wiki/Cognition_AI
# /wiki/Cohere
# /wiki/Contextual_AI
# /wiki/DeepL_Translator
# /wiki/DeepSeek
# /wiki/ElevenLabs
# /wiki/Google_DeepMind
# /wiki/HeyGen
# /wiki/Hugging_Face
# /wiki/Krikey_AI
# /wiki/Kuaishou
# /wiki/Meta_AI
# /wiki/MiniMax_(company)
# /wiki/Mistral_AI
# /wiki/Moonshot_AI
# /wiki/Runway_(company)
# /wiki/Scale_AI
# /wiki/Stability_AI
# /wiki/Synthesia_(company)
# /wiki/Tencent
# /wiki/XAI_(company)
# /wiki/Yandex
# /wiki/Zhipu_AI
# /wiki/Category:Generative_artificial_intelligence
# https://commons.wikimedia.org/wiki/Category:Generative_artificial_intelligence
# /wiki/Template:Existential_risk_from_artificial_intelligence
# /wiki/Template_talk:Existential_risk_from_artificial_intelligence
# /wiki/Special:EditPage/Template:Existential_risk_from_artificial_intelligence
# /wiki/Existential_risk_from_artificial_intelligence
# /wiki/Artificial_intelligence
# /wiki/Artificial_general_intelligence
# /wiki/AI_alignment
# /wiki/AI_boom
# /wiki/AI_capability_control
# /wiki/AI_safety
# /wiki/AI_takeover
# /wiki/Consequentialism
# /wiki/Effective_accelerationism
# /wiki/Ethics_of_artificial_intelligence
# /wiki/Existential_risk_from_artificial_intelligence
# /wiki/Friendly_artificial_intelligence
# /wiki/Instrumental_convergence
# /wiki/Vulnerable_world_hypothesis
# /wiki/Intelligence_explosion
# /wiki/Longtermism
# /wiki/Machine_ethics
# /wiki/Risk_of_astronomical_suffering
# /wiki/Superintelligence
# /wiki/Technological_singularity
# /wiki/Alignment_Research_Center
# /wiki/Center_for_AI_Safety
# /wiki/Center_for_Applied_Rationality
# /wiki/Center_for_Human-Compatible_Artificial_Intelligence
# /wiki/Centre_for_the_Study_of_Existential_Risk
# /wiki/EleutherAI
# /wiki/Future_of_Humanity_Institute
# /wiki/Future_of_Life_Institute
# /wiki/Google_DeepMind
# /wiki/Humanity%2B
# /wiki/Institute_for_Ethics_and_Emerging_Technologies
# /wiki/Leverhulme_Centre_for_the_Future_of_Intelligence
# /wiki/Machine_Intelligence_Research_Institute
# /wiki/Slate_Star_Codex
# /wiki/Sam_Altman
# /wiki/Yoshua_Bengio
# /wiki/Nick_Bostrom
# /wiki/Paul_Christiano_(researcher)
# /wiki/K._Eric_Drexler
# /wiki/Sam_Harris
# /wiki/Stephen_Hawking
# /wiki/Dan_Hendrycks
# /wiki/Geoffrey_Hinton
# /wiki/Bill_Joy
# /wiki/Shane_Legg
# /wiki/Elon_Musk
# /wiki/Steve_Omohundro
# /wiki/Huw_Price
# /wiki/Martin_Rees
# /wiki/Stuart_J._Russell
# /wiki/Jaan_Tallinn
# /wiki/Max_Tegmark
# /wiki/Frank_Wilczek
# /wiki/Roman_Yampolskiy
# /wiki/Eliezer_Yudkowsky
# /wiki/Statement_on_AI_risk_of_extinction
# /wiki/Human_Compatible
# /wiki/Open_letter_on_artificial_intelligence_(2015)
# /wiki/Our_Final_Invention
# /wiki/The_Precipice:_Existential_Risk_and_the_Future_of_Humanity
# /wiki/Superintelligence:_Paths,_Dangers,_Strategies
# /wiki/Do_You_Trust_This_Computer%3F
# /wiki/Artificial_Intelligence_Act
# /wiki/Category:Existential_risk_from_artificial_general_intelligence
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q21708200#identifiers
# https://viaf.org/viaf/279153596615351900003
# https://viaf.org/viaf/69167927872329081135
# https://viaf.org/viaf/3170520164403302936
# https://d-nb.info/gnd/1165529815
# https://id.loc.gov/authorities/no2023052542
# https://id.ndl.go.jp/auth/ndlna/033611207
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ko20231201916&CON_LNG=ENG
# https://dbn.bn.org.pl/descriptor-details/9813168228105606
# https://cantic.bnc.cat/registre/981061049264006706
# https://musicbrainz.org/artist/bf47bbea-ad9c-49de-956b-8fd210d3cb75
# https://www.idref.fr/224627856
# /wiki/Wikipedia:Contents/Portals
# /wiki/Portal:Companies
# /wiki/Portal:San_Francisco_Bay_Area
# /wiki/Portal:California
# https://en.wikipedia.org/w/index.php?title=OpenAI&oldid=1296780953
# /wiki/Help:Category
# /wiki/Category:OpenAI
# /wiki/Category:Artificial_intelligence_associations
# /wiki/Category:Artificial_intelligence_laboratories
# /wiki/Category:Non-profit_organizations_based_in_San_Francisco
# /wiki/Category:501(c)(3)_organizations
# /wiki/Category:Research_institutes_in_the_San_Francisco_Bay_Area
# /wiki/Category:2015_establishments_in_California
# /wiki/Category:2015_in_San_Francisco
# /wiki/Category:American_companies_established_in_2015
# /wiki/Category:CS1_maint:_multiple_names:_authors_list
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Use_American_English_from_May_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Use_mdy_dates_from_September_2024
# /wiki/Category:Articles_with_excerpts
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=OpenAI&mobileaction=toggle_view_mobile
# https://www.wikimedia.org/
# https://www.mediawiki.org/
# #
# #
# #
# #
# #
# #
# #
# #

# %%
# Query the LLM to extract and return only the relevant brochure links
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Run the function on another site (e.g. HuggingFace)
huggingface = Website("https://huggingface.co")
huggingface.links

get_links("https://huggingface.co")

# %%
# === Step 2: Compile Page Contents for Brochure Input ===
# Fetch main content from the homepage and any relevant subpages, to prepare an informative input for brochure generation.

def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

print(get_all_details("https://huggingface.co"))

# %%
# Define the system prompt for brochure generation (can be customized for tone and formality)
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Generate user prompt combining homepage and key subpages
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000]  # Truncate prompt if needed
    return user_prompt

get_brochure_user_prompt("HuggingFace", "https://huggingface.co")

# %%
# === Step 3: Generate the Brochure ===
# Uses OpenAI's GPT model to synthesize structured business content in Markdown format

def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

create_brochure("HuggingFace", "https://huggingface.co")

# === Optional Enhancement: Streamed Response Output ===
# Streams the brochure content to the user with a live typewriter-style animation

def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
        stream=True
    )

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```", "").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# Stream brochure generation for HuggingFace
stream_brochure("HuggingFace", "https://huggingface.co")

# === Tip ===
# Try switching the system prompt to a humorous tone to show how easily the model adapts style.

# %% [markdown]
# # with LLaMA 3.2

# %%
import subprocess
import json
import requests
from bs4 import BeautifulSoup

# -- headers
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

# -- Website class
class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text[:2000]}\n\n"  # limit for LLMs

# -- Prompts
link_system_prompt = """You are provided with a list of links found on a webpage. 
You are able to decide which of the links would be most relevant to include in a brochure about the company, 
such as links to an About page, or a Company page, or Careers/Jobs pages.
You should respond in JSON as in this example:
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

system_prompt = """You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# -- Call LLaMA 3.2 via ollama
def call_llama32(system_prompt, user_prompt):
    prompt = f"<|system|>\n{system_prompt}\n<|user|>\n{user_prompt}\n"
    result = subprocess.run(
        ["ollama", "run", "llama3.2"],
        input=prompt,
        capture_output=True,
        text=True
    )
    return result.stdout.strip()

# -- Build user prompts
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url}. Please decide which are relevant:\n"
    full_links = [link if link.startswith("http") else website.url.rstrip("/") + "/" + link.lstrip("/") for link in website.links]
    user_prompt += "\n".join(full_links)
    return user_prompt

def get_links(url):
    website = Website(url)
    user_prompt = get_links_user_prompt(website)
    response = call_llama32(link_system_prompt, user_prompt)
    try:
        return json.loads(response)
    except Exception as e:
        print("⚠️ Error parsing JSON from LLaMA:", e)
        print("Raw response:\n", response)
        return {"links": []}

def get_all_details(url):
    result = Website(url).get_contents()
    links_info = get_links(url)
    for link in links_info.get("links", []):
        result += f"\n\n{link.get('type', 'Page')}\n"
        result += Website(link["url"]).get_contents()
    return result

def create_brochure(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages:\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:8000]  # Truncate if necessary
    response = call_llama32(system_prompt, user_prompt)
    print("\n--- Generated Brochure ---\n")
    print(response)

# -- Run
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# --- Generated Brochure ---
#
# # Hugging Face Brochure
#
# ## About Us
#
# Hugging Face is the AI community building the future. Our platform is where machine learning professionals collaborate on models, datasets, and applications. We provide a collaboration environment that enables users to create, discover, and share knowledge in the field of artificial intelligence.
#
# ### Company Culture
#
# At Hugging Face, we value innovation, community, and transparency. We believe that open-source technology can democratize access to AI and drive progress in various fields. Our team is comprised of passionate individuals who strive to make a positive impact through our work.
#
# ### Customers
#
# We serve a diverse range of customers, including:
#
# * Machine learning researchers
# * Developers building AI applications
# * Data scientists working on large-scale projects
# * Students looking for resources to learn and experiment with AI
#
# Our platform offers a wide range of tools and models that cater to the needs of these customers, from text generation to image-to-3D generation.
#
# ### Careers/Jobs
#
# If you're passionate about AI and want to join our team, we have various job opportunities available. Our careers page features openings for software engineers, data scientists, researchers, and more. You can find out more about our company culture and values on our [About Us](#about-us) page.
#
# ### What We Offer
#
# We provide a comprehensive platform that includes:
#
# * **Models**: Access to over 1 million pre-trained models for various tasks, including text generation, image classification, and more.
# * **Datasets**: A vast collection of datasets for training and testing AI models.
# * **Spaces**: A collaboration environment where users can host and collaborate on public models, datasets, and applications.
# * **Compute**: Paid compute solutions for deploying and running AI models.
# * **Enterprise**: Advanced platform for teams to build and deploy AI applications with enterprise-grade security and access controls.
#
# ## Explore Our Features
#
# Our platform offers a wide range of features that cater to the needs of machine learning professionals. Some of our notable features include:
#
# * **Text Generation**: Generate text based on prompts or input data.
# * **Image-to-3D Generation**: Convert 2D images into 3D models.
# * **Image-Text-to-Text**: Translate images into text.
# * **Text-to-Video**: Create videos from text-based content.
#
# ## Join the Hugging Face Community
#
# Join our community of machine learning professionals and start exploring the possibilities of AI. Sign up for our platform today and experience the power of open-source technology in action.
#
# [Sign Up](#sign-up)
#
# [Learn More About Our Platform](#learn-more-about-our-platform)

# %%
import time
from IPython.display import Markdown, display, update_display

def stream_brochure(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages:\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:8000]

    full_response = call_llama32(system_prompt, user_prompt)

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for char in full_response:
        response += char
        if char in [".", "\n"]:
            update_display(Markdown(response), display_id=display_handle.display_id)
            time.sleep(0.05)
    update_display(Markdown(response), display_id=display_handle.display_id)

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# **Welcome to Hugging Face: The AI Community Building the Future**
#
# Hugging Face is a platform that brings together the machine learning community to collaborate on models, datasets, and applications. Our mission is to accelerate the development of artificial intelligence by providing a collaborative environment for researchers, developers, and innovators.
#
# **Our Mission**
#
# At Hugging Face, we believe that the future of AI depends on collaboration, openness, and accessibility. That's why we've created a platform that allows users to create, discover, and collaborate on ML models, datasets, and applications. Our goal is to make AI more accessible and user-friendly, empowering individuals and organizations to build innovative solutions.
#
# **Our Community**
#
# Hugging Face has a vibrant community of researchers, developers, and innovators from around the world. Our community is driven by a shared passion for AI and a commitment to collaboration, openness, and innovation. We believe that our community is the key to unlocking the full potential of AI.
#
# **What We Offer**
#
# * **Models**: We offer a vast library of pre-trained models, including state-of-the-art models in natural language processing, computer vision, and other areas.
# * **Datasets**: Our dataset repository contains millions of datasets, making it easy for users to find and utilize high-quality data for their AI projects.
# * **Spaces**: Hugging Face Spaces allows users to host and collaborate on unlimited public models, datasets, and applications.
# * **Compute**: We provide paid Compute solutions that enable users to deploy and run AI models quickly and efficiently.
#
# **Our Values**
#
# At Hugging Face, we value:
#
# * **Collaboration**: We believe that collaboration is key to unlocking the full potential of AI.
# * **Openness**: We're committed to openness and accessibility in all aspects of our platform.
# * **Innovation**: We encourage innovation and experimentation, empowering users to build innovative solutions.
#
# **Join Our Community**
#
# If you're passionate about AI and want to be part of a vibrant community of innovators, join us today! Sign up for our platform, explore our models and datasets, and start building your own AI projects.
